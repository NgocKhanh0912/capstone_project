# %%
import os
import numpy as np
import pandas as pd

# %%
def terma_detect_peaks(input_dir, output_dir, w_cycle=55, w_evt=9, beta=0.095):
    """
    Processes multiple PPG files, detects peaks, and saves the results into CSV files.
    
    Parameters:
    - input_dir: Path to the directory containing input PPG files.
    - output_dir: Path to the directory where the output files will be saved.
    - w_cycle: Window size for calculating the cycle moving average.
    - w_evt: Window size for calculating the event moving average.
    - beta: Scaling factor for the threshold.
    """
    
    # Loop over all files in the input directory
    for file_name in os.listdir(input_dir):
        if file_name.endswith('.csv'):  # Process only CSV files
            input_file = os.path.join(input_dir, file_name)
            print(f"Processing file: {file_name}")
            
            # Read the PPG data from the file
            ppg_data = pd.read_csv(input_file, header=None)
            signal = np.asarray(ppg_data.iloc[:, 0], dtype=np.float64)  # Assume the PPG data is in the first column
            
            # Shift the signal to eliminate negative values
            min_signal = np.min(signal)
            if min_signal < 0:
                signal = signal - min_signal  # Shift signal so the minimum value becomes 0 or greater
            
            # Enhance the signal (square the values)
            signal = signal * signal
            
            # Initialize arrays for moving averages and thresholds
            ma_cycle = np.zeros_like(signal, dtype=np.float64)
            ma_evt = np.zeros_like(signal, dtype=np.float64)
            mean_signal = np.mean(signal)
            mean = np.full(len(signal), mean_signal)
            threshold_1 = np.zeros_like(signal, dtype=np.float64)
            block_of_interest = np.zeros_like(signal, dtype=np.float64)
            peak_index_arr = []
            
            # Calculate the Event Duration Moving Average
            for i in range((w_evt - 1) // 2, len(signal) - ((w_evt - 1) // 2)):
                ma_evt[i] = np.mean(signal[i - (w_evt - 1) // 2 : i + (w_evt - 1) // 2 + 1])
            
            # Calculate the Event Cycle Moving Average
            for i in range((w_cycle - 1) // 2, len(signal) - ((w_cycle - 1) // 2)):
                ma_cycle[i] = np.mean(signal[i - (w_cycle - 1) // 2 : i + (w_cycle - 1) // 2 + 1])
            
            # Calculate the Threshold for Block of Interest
            for i in range(len(signal)):
                threshold_1[i] = ma_cycle[i] + beta * mean[i]
            
            # Generate the Block of Interest
            for i in range(len(signal)):
                if (ma_evt[i] > threshold_1[i]) and (ma_cycle[i] != 0):
                    block_of_interest[i] = 1
                else:
                    block_of_interest[i] = 0
            
            # Peak detector logic
            start_block = 0
            stop_block = 0
            peak = 0
            peak_index = 0
            block_num = 0
            
            for i in range(len(block_of_interest) - 1):
                if (block_of_interest[i + 1] - block_of_interest[i]) == 1:
                    start_block = i
                if (block_of_interest[i] - block_of_interest[i + 1]) == 1:
                    stop_block = i
                    if (stop_block - start_block) >= w_evt:
                        peak = signal[start_block]
                        for j in range(start_block, stop_block + 1):
                            if signal[j] > peak:
                                peak = signal[j]
                                peak_index = j
                        peak_index_arr.append(peak_index)
                        block_num += 1
            
            # Save the peak indices to a CSV file
            output_file = os.path.join(output_dir, f"{file_name.replace('.csv', '')}_labeled_peaks.csv")
            pd.DataFrame(peak_index_arr).to_csv(output_file, header=False, index=False)
            print(f"Peaks saved to: {output_file}")

# %%
input_folder = 'E:/dilated_cnn_peak_detection_model_data/train/train_data/data'
output_folder = 'E:/dilated_cnn_peak_detection_model_data/train/train_data/label'

terma_detect_peaks(input_folder, output_folder)

input_folder1 = 'E:/dilated_cnn_peak_detection_model_data/test/test_data/data'
output_folder1 = 'E:/dilated_cnn_peak_detection_model_data/test/test_data/label'

terma_detect_peaks(input_folder1, output_folder1)
# Out:
# Processing file: mimic_perform_af_004_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_af_004_data_labeled_peaks.csv
# Processing file: mimic_perform_af_005_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_af_005_data_labeled_peaks.csv
# Processing file: mimic_perform_af_006_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_af_006_data_labeled_peaks.csv
# Processing file: mimic_perform_af_007_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_af_007_data_labeled_peaks.csv
# Processing file: mimic_perform_af_008_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_af_008_data_labeled_peaks.csv
# Processing file: mimic_perform_af_009_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_af_009_data_labeled_peaks.csv
# Processing file: mimic_perform_af_010_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_af_010_data_labeled_peaks.csv
# Processing file: mimic_perform_af_011_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_af_011_data_labeled_peaks.csv
# Processing file: mimic_perform_af_012_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_af_012_data_labeled_peaks.csv
# Processing file: mimic_perform_af_013_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_af_013_data_labeled_peaks.csv
# Processing file: mimic_perform_af_014_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_af_014_data_labeled_peaks.csv
# Processing file: mimic_perform_af_015_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_af_015_data_labeled_peaks.csv
# Processing file: mimic_perform_af_016_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_af_016_data_labeled_peaks.csv
# Processing file: mimic_perform_af_017_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_af_017_data_labeled_peaks.csv
# Processing file: mimic_perform_af_018_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_af_018_data_labeled_peaks.csv
# Processing file: mimic_perform_af_019_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_af_019_data_labeled_peaks.csv
# Processing file: mimic_perform_non_af_004_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_non_af_004_data_labeled_peaks.csv
# Processing file: mimic_perform_non_af_005_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_non_af_005_data_labeled_peaks.csv
# Processing file: mimic_perform_non_af_006_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_non_af_006_data_labeled_peaks.csv
# Processing file: mimic_perform_non_af_007_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_non_af_007_data_labeled_peaks.csv
# Processing file: mimic_perform_non_af_008_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_non_af_008_data_labeled_peaks.csv
# Processing file: mimic_perform_non_af_009_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_non_af_009_data_labeled_peaks.csv
# Processing file: mimic_perform_non_af_010_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_non_af_010_data_labeled_peaks.csv
# Processing file: mimic_perform_non_af_011_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_non_af_011_data_labeled_peaks.csv
# Processing file: mimic_perform_non_af_012_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_non_af_012_data_labeled_peaks.csv
# Processing file: mimic_perform_non_af_013_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_non_af_013_data_labeled_peaks.csv
# Processing file: mimic_perform_non_af_014_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_non_af_014_data_labeled_peaks.csv
# Processing file: mimic_perform_non_af_015_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_non_af_015_data_labeled_peaks.csv
# Processing file: mimic_perform_non_af_016_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_non_af_016_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_004_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_004_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_005_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_005_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_006_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_006_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_007_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_007_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_008_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_008_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_009_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_009_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_010_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_010_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_011_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_011_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_012_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_012_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_013_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_013_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_014_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_014_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_015_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_015_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_016_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_016_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_017_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_017_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_018_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_018_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_019_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_019_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_020_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_020_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_021_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_021_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_022_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_022_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_023_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_023_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_024_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_024_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_025_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_025_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_026_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_026_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_027_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_027_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_028_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_028_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_029_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_029_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_030_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_030_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_031_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_031_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_032_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_032_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_033_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_033_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_034_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_034_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_035_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_035_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_036_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_036_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_037_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_037_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_038_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_038_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_039_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_039_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_040_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_040_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_041_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_041_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_042_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_042_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_043_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_043_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_044_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_044_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_045_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_045_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_046_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_046_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_047_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_047_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_048_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_048_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_049_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_049_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_050_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_050_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_051_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_051_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_052_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_052_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_053_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_053_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_054_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_054_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_055_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_055_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_056_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_056_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_057_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_057_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_058_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_058_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_059_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_059_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_060_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_060_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_061_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_061_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_062_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_062_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_063_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_063_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_064_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_064_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_065_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_065_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_066_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_066_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_067_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_067_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_068_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_068_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_069_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_069_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_070_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_070_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_071_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_071_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_072_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_072_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_073_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_073_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_074_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_074_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_075_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_075_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_076_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_076_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_077_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_077_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_078_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_078_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_079_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_079_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_080_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_080_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_081_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_081_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_082_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_082_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_083_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_083_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_084_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_084_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_085_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_085_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_086_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_086_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_087_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_087_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_088_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_088_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_089_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_089_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_090_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_090_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_091_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_091_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_092_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_092_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_093_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_093_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_094_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_094_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_095_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_095_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_096_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_096_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_097_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_097_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_098_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_098_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_099_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_099_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_100_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_100_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_101_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_101_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_102_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_102_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_103_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_103_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_104_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_104_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_105_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_105_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_106_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_106_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_107_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_107_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_108_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_108_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_109_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_109_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_110_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_110_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_111_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_111_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_112_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_112_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_113_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_113_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_114_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_114_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_115_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_115_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_116_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_116_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_117_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_117_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_118_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_118_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_119_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_119_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_120_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_120_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_121_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_121_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_122_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_122_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_123_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_123_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_124_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_124_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_125_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_125_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_126_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_126_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_127_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_127_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_128_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_128_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_129_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_129_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_130_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_130_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_131_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_131_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_132_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_132_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_133_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_133_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_134_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_134_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_135_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_135_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_136_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_136_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_137_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_137_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_138_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_138_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_139_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_139_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_140_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_140_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_141_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_141_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_142_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_142_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_143_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_143_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_144_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_144_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_145_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_145_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_146_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_146_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_147_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_147_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_148_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_148_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_149_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_149_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_150_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_150_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_151_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_151_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_152_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_152_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_153_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_153_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_154_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_154_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_155_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_155_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_156_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_156_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_157_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_157_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_158_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_158_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_159_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_159_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_160_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_160_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_161_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_161_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_162_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_162_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_163_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_163_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_164_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_164_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_165_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_165_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_166_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_166_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_167_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_167_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_168_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_168_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_169_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_169_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_170_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_170_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_171_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_171_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_172_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_172_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_173_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_173_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_174_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_174_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_175_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_175_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_176_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_176_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_177_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_177_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_178_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_178_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_179_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_179_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_180_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_180_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_181_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_181_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_182_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_182_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_183_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_183_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_184_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_184_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_185_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_185_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_186_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_186_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_187_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_187_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_188_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_188_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_189_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_189_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_190_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_190_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_191_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_191_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_192_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_192_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_193_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_193_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_194_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_194_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_195_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_195_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_196_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_196_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_197_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_197_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_198_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_198_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_199_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_199_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_200_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\mimic_perform_test_all_200_data_labeled_peaks.csv
# Processing file: p015852-2148-05-03-18-39.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p015852-2148-05-03-18-39_labeled_peaks.csv
# Processing file: p016684-2188-01-29-00-06.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p016684-2188-01-29-00-06_labeled_peaks.csv
# Processing file: p019608-2125-02-05-04-57.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p019608-2125-02-05-04-57_labeled_peaks.csv
# Processing file: p022954-2136-02-29-17-52.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p022954-2136-02-29-17-52_labeled_peaks.csv
# Processing file: p023824-2182-11-27-14-22.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p023824-2182-11-27-14-22_labeled_peaks.csv
# Processing file: p025117-2202-03-15-20-28.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p025117-2202-03-15-20-28_labeled_peaks.csv
# Processing file: p025117-2202-03-17-09-14.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p025117-2202-03-17-09-14_labeled_peaks.csv
# Processing file: p026377-2111-11-17-16-46.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p026377-2111-11-17-16-46_labeled_peaks.csv
# Processing file: p026964-2143-09-30-11-59.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p026964-2143-09-30-11-59_labeled_peaks.csv
# Processing file: p026964-2147-01-11-18-03.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p026964-2147-01-11-18-03_labeled_peaks.csv
# Processing file: p029512-2188-02-27-18-10.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p029512-2188-02-27-18-10_labeled_peaks.csv
# Processing file: p043613-2185-01-18-23-52.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p043613-2185-01-18-23-52_labeled_peaks.csv
# Processing file: p050089-2157-08-23-16-37.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p050089-2157-08-23-16-37_labeled_peaks.csv
# Processing file: p050384-2195-01-30-02-21.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p050384-2195-01-30-02-21_labeled_peaks.csv
# Processing file: p050384-2195-01-30-16-17.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p050384-2195-01-30-16-17_labeled_peaks.csv
# Processing file: p055204-2132-06-30-09-34.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p055204-2132-06-30-09-34_labeled_peaks.csv
# Processing file: p055204-2132-07-02-00-25.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p055204-2132-07-02-00-25_labeled_peaks.csv
# Processing file: p058932-2120-10-13-23-15.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p058932-2120-10-13-23-15_labeled_peaks.csv
# Processing file: p062160-2153-10-03-05-39.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p062160-2153-10-03-05-39_labeled_peaks.csv
# Processing file: p062160-2153-10-03-14-49.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p062160-2153-10-03-14-49_labeled_peaks.csv
# Processing file: p063039-2157-03-29-13-35.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p063039-2157-03-29-13-35_labeled_peaks.csv
# Processing file: p063628-2176-07-02-20-38.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p063628-2176-07-02-20-38_labeled_peaks.csv
# Processing file: p063628-2176-07-04-11-30.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p063628-2176-07-04-11-30_labeled_peaks.csv
# Processing file: p063628-2176-07-05-17-12.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p063628-2176-07-05-17-12_labeled_peaks.csv
# Processing file: p068956-2107-04-21-16-05.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p068956-2107-04-21-16-05_labeled_peaks.csv
# Processing file: p068956-2107-04-21-16-10.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p068956-2107-04-21-16-10_labeled_peaks.csv
# Processing file: p069339-2133-12-09-21-14.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p069339-2133-12-09-21-14_labeled_peaks.csv
# Processing file: p069339-2133-12-10-22-32.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p069339-2133-12-10-22-32_labeled_peaks.csv
# Processing file: p075371-2119-08-22-00-53.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p075371-2119-08-22-00-53_labeled_peaks.csv
# Processing file: p075371-2119-08-22-17-30.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p075371-2119-08-22-17-30_labeled_peaks.csv
# Processing file: p075796-2198-05-18-21-46.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p075796-2198-05-18-21-46_labeled_peaks.csv
# Processing file: p075796-2198-05-19-16-50.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p075796-2198-05-19-16-50_labeled_peaks.csv
# Processing file: p075796-2198-07-25-22-55.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p075796-2198-07-25-22-55_labeled_peaks.csv
# Processing file: p075796-2198-07-25-23-40.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p075796-2198-07-25-23-40_labeled_peaks.csv
# Processing file: p077729-2120-08-31-01-03.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p077729-2120-08-31-01-03_labeled_peaks.csv
# Processing file: p077729-2120-08-31-17-38.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p077729-2120-08-31-17-38_labeled_peaks.csv
# Processing file: p079998-2101-10-21-21-31.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p079998-2101-10-21-21-31_labeled_peaks.csv
# Processing file: p081349-2120-02-11-06-35.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p081349-2120-02-11-06-35_labeled_peaks.csv
# Processing file: p081349-2120-02-11-20-56.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p081349-2120-02-11-20-56_labeled_peaks.csv
# Processing file: p085866-2178-03-20-17-11.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p085866-2178-03-20-17-11_labeled_peaks.csv
# Processing file: p087275-2108-08-29-12-53.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p087275-2108-08-29-12-53_labeled_peaks.csv
# Processing file: p087275-2108-09-27-12-32.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p087275-2108-09-27-12-32_labeled_peaks.csv
# Processing file: p087275-2108-09-28-18-46.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p087275-2108-09-28-18-46_labeled_peaks.csv
# Processing file: p087675-2104-12-04-20-08.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p087675-2104-12-04-20-08_labeled_peaks.csv
# Processing file: p087675-2104-12-05-03-53.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p087675-2104-12-05-03-53_labeled_peaks.csv
# Processing file: p089565-2174-05-12-00-07.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p089565-2174-05-12-00-07_labeled_peaks.csv
# Processing file: p089565-2174-05-13-13-03.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p089565-2174-05-13-13-03_labeled_peaks.csv
# Processing file: p092289-2183-03-17-23-12.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p092289-2183-03-17-23-12_labeled_peaks.csv
# Processing file: p092846-2129-12-21-13-12.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p092846-2129-12-21-13-12_labeled_peaks.csv
# Processing file: p094847-2112-02-12-19-56.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p094847-2112-02-12-19-56_labeled_peaks.csv
# Processing file: p094847-2112-02-14-06-52.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p094847-2112-02-14-06-52_labeled_peaks.csv
# Processing file: p097547-2125-10-21-23-43.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/train/train_data/label\p097547-2125-10-21-23-43_labeled_peaks.csv
# Processing file: golden_ppg_data_100hz.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/test/test_data/label\golden_ppg_data_100hz_labeled_peaks.csv
# Processing file: mimic_perform_af_001_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/test/test_data/label\mimic_perform_af_001_data_labeled_peaks.csv
# Processing file: mimic_perform_af_002_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/test/test_data/label\mimic_perform_af_002_data_labeled_peaks.csv
# Processing file: mimic_perform_af_003_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/test/test_data/label\mimic_perform_af_003_data_labeled_peaks.csv
# Processing file: mimic_perform_non_af_001_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/test/test_data/label\mimic_perform_non_af_001_data_labeled_peaks.csv
# Processing file: mimic_perform_non_af_002_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/test/test_data/label\mimic_perform_non_af_002_data_labeled_peaks.csv
# Processing file: mimic_perform_non_af_003_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/test/test_data/label\mimic_perform_non_af_003_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_001_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/test/test_data/label\mimic_perform_test_all_001_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_002_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/test/test_data/label\mimic_perform_test_all_002_data_labeled_peaks.csv
# Processing file: mimic_perform_test_all_003_data.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/test/test_data/label\mimic_perform_test_all_003_data_labeled_peaks.csv
# Processing file: p000946-2120-05-14-08-08.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/test/test_data/label\p000946-2120-05-14-08-08_labeled_peaks.csv
# Processing file: p004829-2103-08-30-21-52.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/test/test_data/label\p004829-2103-08-30-21-52_labeled_peaks.csv
# Processing file: p013072-2194-01-22-16-13.csv
# Peaks saved to: E:/dilated_cnn_peak_detection_model_data/test/test_data/label\p013072-2194-01-22-16-13_labeled_peaks.csv
