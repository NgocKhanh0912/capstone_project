# %%
import wfdb
import pandas as pd
import os

# %%
def extract_heart_rate_data(subject_dir, subject_id, output_dir):  
    """  
    Extract and save heart rate data from numerics WFDB files for a given subject ID.

    Args:  
        subject_dir (str): Path to the directory containing all files for the subject ID.  
        subject_id (str): Subject ID.  
        output_dir (str): Output directory to save the labeled heart rate to CSV files.  
    """  
    try:   
        for file_name in os.listdir(subject_dir):  
            if file_name.endswith('n.hea') and file_name.startswith(subject_id):  
                hea_path = os.path.join(subject_dir, file_name[:-4]) 
 
                record = wfdb.rdrecord(hea_path)

                if 'HR' in record.sig_name:
                    heart_rate_values = record.p_signal[:, record.sig_name.index('HR')]

                    # Remove any invalid or missing values (e.g., NaN, empty strings)  
                    heart_rate_values_cleaned = [x for x in heart_rate_values if pd.notna(x)]

                    heart_rates_df = pd.DataFrame(heart_rate_values_cleaned)

                    heart_rates_file_name = file_name.replace('n.hea', '_labeled_heart_rates.csv')
                    heart_rates_csv_file = os.path.join(output_dir, heart_rates_file_name)  
                    heart_rates_df.to_csv(heart_rates_csv_file, index=False, header=False)   
  
                    print(f"Heart Rate data saved to {heart_rates_csv_file}")
                else:
                    print("Heart Rate signal not found in the record.")
                
    except Exception as e:  
        print(f"Error processing subject directory: {e}")

# %%
# List of subject IDs  
subject_ids = ['p000608', 'p000776', 'p000946', 'p004490', 'p004829',  
               'p009526', 'p010391', 'p013072', 'p013136', 'p014079',  
               'p015852', 'p016684', 'p017344', 'p019608', 'p022954',  
               'p023824', 'p025117', 'p026377', 'p026964', 'p029512',  
               'p043613', 'p050089', 'p050384', 'p055204', 'p058932',  
               'p062160', 'p063039', 'p063628', 'p068956', 'p069339',  
               'p075371', 'p075796', 'p077729', 'p079998', 'p081349',  
               'p085866', 'p087275', 'p087675', 'p089565', 'p089964',  
               'p092289', 'p092846', 'p094847', 'p097547', 'p099674']  

base_subject_dir = 'I:/mimic_dataset/wfdb_dataset_125hz'  
base_output_dir = 'I:/mimic_dataset/heart_rates_csv'  

for subject_id in subject_ids:  
    subject_directory = os.path.join(base_subject_dir, subject_id)  
    output_directory = os.path.join(base_output_dir, subject_id)

    os.makedirs(output_directory, exist_ok=True)  

    extract_heart_rate_data(subject_directory, subject_id, output_directory)
# Out:
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p000608\p000608-2167-03-09-11-54_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p000608\p000608-2167-03-23-08-12_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p000608\p000608-2167-03-24-19-50_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p000776\p000776-2184-04-30-15-16_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p000946\p000946-2120-05-14-08-08_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p004490\p004490-2151-01-07-12-36_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p004490\p004490-2151-01-08-14-56_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p004829\p004829-2103-08-30-21-52_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p009526\p009526-2113-11-17-02-12_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p009526\p009526-2113-11-17-13-13_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p010391\p010391-2183-12-25-10-15_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p013072\p013072-2194-01-16-19-42_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p013072\p013072-2194-01-17-09-48_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p013072\p013072-2194-01-22-16-13_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p013136\p013136-2133-11-09-16-58_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p013136\p013136-2133-11-10-14-55_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p014079\p014079-2182-09-24-13-41_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p015852\p015852-2148-05-03-18-39_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p016684\p016684-2188-01-29-00-06_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p017344\p017344-2169-07-17-14-33_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p017344\p017344-2169-07-17-17-32_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p019608\p019608-2125-02-05-04-57_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p022954\p022954-2136-02-29-17-52_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p023824\p023824-2182-11-27-14-22_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p025117\p025117-2202-03-15-20-28_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p025117\p025117-2202-03-17-09-15_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p026377\p026377-2111-11-17-16-45_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p026964\p026964-2143-09-30-11-59_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p026964\p026964-2147-01-11-18-03_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p029512\p029512-2188-02-27-18-10_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p043613\p043613-2185-01-18-23-52_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p050089\p050089-2157-08-23-16-37_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p050384\p050384-2195-01-30-02-21_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p050384\p050384-2195-01-30-16-17_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p055204\p055204-2132-06-30-09-34_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p058932\p058932-2120-10-13-23-15_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p062160\p062160-2153-10-03-05-39_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p062160\p062160-2153-10-03-14-49_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p063039\p063039-2157-03-29-13-35_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p063628\p063628-2176-07-02-20-37_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p063628\p063628-2176-07-04-11-30_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p063628\p063628-2176-07-05-17-12_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p068956\p068956-2107-04-21-16-05_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p068956\p068956-2107-04-21-16-10_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p069339\p069339-2133-12-09-21-14_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p069339\p069339-2133-12-10-22-32_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p075371\p075371-2119-08-22-00-53_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p075371\p075371-2119-08-22-17-30_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p075796\p075796-2198-05-18-21-46_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p075796\p075796-2198-05-19-16-50_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p075796\p075796-2198-07-25-22-55_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p075796\p075796-2198-07-25-23-40_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p077729\p077729-2120-08-31-01-03_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p079998\p079998-2101-10-21-21-31_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p081349\p081349-2120-02-11-06-35_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p081349\p081349-2120-02-11-20-56_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p085866\p085866-2178-03-20-17-11_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p087275\p087275-2108-08-29-12-53_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p087275\p087275-2108-09-27-12-32_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p087275\p087275-2108-09-28-18-46_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p087675\p087675-2104-12-04-20-08_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p087675\p087675-2104-12-05-03-53_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p089565\p089565-2174-05-12-00-07_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p089565\p089565-2174-05-13-13-03_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p089964\p089964-2154-05-21-14-53_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p089964\p089964-2154-05-22-07-45_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p092289\p092289-2183-03-17-23-12_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p092846\p092846-2129-12-21-13-12_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p094847\p094847-2112-02-12-19-56_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p094847\p094847-2112-02-14-06-52_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p097547\p097547-2125-10-21-23-43_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p099674\p099674-2105-06-12-21-00_labeled_heart_rates.csv
# Heart Rate data saved to I:/mimic_dataset/heart_rates_csv\p099674\p099674-2105-06-13-00-07_labeled_heart_rates.csv
