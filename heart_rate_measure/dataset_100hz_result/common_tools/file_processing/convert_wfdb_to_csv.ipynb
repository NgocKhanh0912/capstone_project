# %%
import wfdb
import pandas as pd
import os
import re

# %%
def aggregate_wf_files(subject_dir, subject_id, output_dir):  
    """  
    Aggregate data from WF files corresponding to a subject ID into separate CSV files for each WF file name,  
    and combine all PPG values into a single file named after the .hea file, only if PPG data is available.  

    Args:  
        subject_dir (str): Path to the directory containing all files for the subject ID.  
        subject_id (str): Subject ID.  
        output_dir (str): Output directory to save the CSV files.  
    """  
    
    ppg_data_found = False  

    try:   
        for file_name in os.listdir(subject_dir):  
            if file_name.endswith('.hea') and file_name.startswith(subject_id) and not file_name[-5] == 'n':  
                hea_path = os.path.join(subject_dir, file_name)  
 
                with open(hea_path, 'r') as hea_file:  
                    lines = hea_file.readlines()  
  
                available_files = {os.path.splitext(f)[0] for f in os.listdir(subject_dir)}  

                combined_ppg_data = []  

                for line in lines:  
                    matches = re.findall(r'\b\d{7}_\d{4}\b', line)  
                    for match in matches:  
                        if match in available_files:  
                            wf_path = os.path.join(subject_dir, match)  
                            try:  
                                record = wfdb.rdrecord(wf_path)  
 
                                if 'PLETH' in record.sig_name:  
                                    # Extract PPG signal  
                                    ppg_data = record.p_signal[:, record.sig_name.index('PLETH')]  

                                    # Replace any invalid or missing values (e.g., NaN, empty strings) with 0  
                                    ppg_data_cleaned = [0 if pd.isna(x) else x for x in ppg_data]  

                                    combined_ppg_data.extend(ppg_data_cleaned)  
                                    ppg_data_found = True  

                            except Exception as e:  
                                print(f"Error processing {match}: {e}")  

                if ppg_data_found:  
                    if not os.path.exists(output_dir):  
                        os.makedirs(output_dir)

                    combined_file_name = os.path.splitext(file_name)[0] + ".csv"  
                    combined_csv_file = os.path.join(output_dir, combined_file_name)  

                    combined_df = pd.DataFrame(combined_ppg_data)  
 
                    combined_df.to_csv(combined_csv_file, index=False, header=False)  
                    print(f"All PPG data from {file_name[:-4]} has been combined and saved to {combined_csv_file}.")  

    except Exception as e:  
        print(f"Error processing subject directory: {e}")

# %%
# List of subject IDs  
subject_ids = ['p000608', 'p000776', 'p000946', 'p004490', 'p004829',  
               'p009526', 'p010391', 'p013072', 'p013136', 'p014079',  
               'p015852', 'p016684', 'p017344', 'p019608', 'p022954',  
               'p023824', 'p025117', 'p026377', 'p026964', 'p029512',  
               'p043613', 'p050089', 'p050384', 'p055204', 'p058932',  
               'p062160', 'p063039', 'p063628', 'p068956', 'p069339',  
               'p075371', 'p075796', 'p077729', 'p079998', 'p081349',  
               'p085866', 'p087275', 'p087675', 'p089565', 'p089964',  
               'p092289', 'p092846', 'p094847', 'p097547', 'p099674']  

base_subject_dir = 'I:/mimic_dataset/wfdb_dataset_125hz'  
base_output_dir = 'I:/mimic_dataset/csv_dataset_125hz'  

for subject_id in subject_ids:  
    subject_directory = os.path.join(base_subject_dir, subject_id)  
    output_directory = os.path.join(base_output_dir, subject_id)  

    aggregate_wf_files(subject_directory, subject_id, output_directory)
# Out:
# All PPG data from p000946-2120-05-14-08-08 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p000946\p000946-2120-05-14-08-08.csv.
# All PPG data from p004829-2103-08-30-21-52 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p004829\p004829-2103-08-30-21-52.csv.
# All PPG data from p013072-2194-01-22-16-13 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p013072\p013072-2194-01-22-16-13.csv.
# All PPG data from p015852-2148-05-03-18-39 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p015852\p015852-2148-05-03-18-39.csv.
# All PPG data from p016684-2188-01-29-00-06 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p016684\p016684-2188-01-29-00-06.csv.
# All PPG data from p019608-2125-02-05-04-57 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p019608\p019608-2125-02-05-04-57.csv.
# All PPG data from p022954-2136-02-29-17-52 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p022954\p022954-2136-02-29-17-52.csv.
# All PPG data from p023824-2182-11-27-14-22 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p023824\p023824-2182-11-27-14-22.csv.
# All PPG data from p025117-2202-03-15-20-28 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p025117\p025117-2202-03-15-20-28.csv.
# All PPG data from p025117-2202-03-17-09-14 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p025117\p025117-2202-03-17-09-14.csv.
# All PPG data from p026377-2111-11-17-16-46 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p026377\p026377-2111-11-17-16-46.csv.
# All PPG data from p026964-2143-09-30-11-59 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p026964\p026964-2143-09-30-11-59.csv.
# All PPG data from p026964-2147-01-11-18-03 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p026964\p026964-2147-01-11-18-03.csv.
# All PPG data from p029512-2188-02-27-18-10 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p029512\p029512-2188-02-27-18-10.csv.
# All PPG data from p043613-2185-01-18-23-52 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p043613\p043613-2185-01-18-23-52.csv.
# All PPG data from p050089-2157-08-23-16-37 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p050089\p050089-2157-08-23-16-37.csv.
# All PPG data from p050384-2195-01-30-02-21 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p050384\p050384-2195-01-30-02-21.csv.
# All PPG data from p050384-2195-01-30-16-17 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p050384\p050384-2195-01-30-16-17.csv.
# All PPG data from p055204-2132-06-30-09-34 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p055204\p055204-2132-06-30-09-34.csv.
# All PPG data from p055204-2132-07-02-00-25 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p055204\p055204-2132-07-02-00-25.csv.
# All PPG data from p058932-2120-10-13-23-15 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p058932\p058932-2120-10-13-23-15.csv.
# All PPG data from p062160-2153-10-03-05-39 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p062160\p062160-2153-10-03-05-39.csv.
# All PPG data from p062160-2153-10-03-14-49 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p062160\p062160-2153-10-03-14-49.csv.
# All PPG data from p063039-2157-03-29-13-35 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p063039\p063039-2157-03-29-13-35.csv.
# All PPG data from p063628-2176-07-02-20-38 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p063628\p063628-2176-07-02-20-38.csv.
# All PPG data from p063628-2176-07-04-11-30 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p063628\p063628-2176-07-04-11-30.csv.
# All PPG data from p063628-2176-07-05-17-12 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p063628\p063628-2176-07-05-17-12.csv.
# All PPG data from p068956-2107-04-21-16-05 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p068956\p068956-2107-04-21-16-05.csv.
# All PPG data from p068956-2107-04-21-16-10 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p068956\p068956-2107-04-21-16-10.csv.
# All PPG data from p069339-2133-12-09-21-14 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p069339\p069339-2133-12-09-21-14.csv.
# All PPG data from p069339-2133-12-10-22-32 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p069339\p069339-2133-12-10-22-32.csv.
# All PPG data from p075371-2119-08-22-00-53 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p075371\p075371-2119-08-22-00-53.csv.
# All PPG data from p075371-2119-08-22-17-30 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p075371\p075371-2119-08-22-17-30.csv.
# All PPG data from p075796-2198-05-18-21-46 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p075796\p075796-2198-05-18-21-46.csv.
# All PPG data from p075796-2198-05-19-16-50 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p075796\p075796-2198-05-19-16-50.csv.
# All PPG data from p075796-2198-07-25-22-55 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p075796\p075796-2198-07-25-22-55.csv.
# All PPG data from p075796-2198-07-25-23-40 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p075796\p075796-2198-07-25-23-40.csv.
# All PPG data from p077729-2120-08-31-01-03 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p077729\p077729-2120-08-31-01-03.csv.
# All PPG data from p077729-2120-08-31-17-38 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p077729\p077729-2120-08-31-17-38.csv.
# All PPG data from p079998-2101-10-21-21-31 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p079998\p079998-2101-10-21-21-31.csv.
# All PPG data from p081349-2120-02-11-06-35 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p081349\p081349-2120-02-11-06-35.csv.
# All PPG data from p081349-2120-02-11-20-56 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p081349\p081349-2120-02-11-20-56.csv.
# All PPG data from p085866-2178-03-20-17-11 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p085866\p085866-2178-03-20-17-11.csv.
# All PPG data from p087275-2108-08-29-12-53 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p087275\p087275-2108-08-29-12-53.csv.
# All PPG data from p087275-2108-09-27-12-32 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p087275\p087275-2108-09-27-12-32.csv.
# All PPG data from p087275-2108-09-28-18-46 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p087275\p087275-2108-09-28-18-46.csv.
# All PPG data from p087675-2104-12-04-20-08 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p087675\p087675-2104-12-04-20-08.csv.
# All PPG data from p087675-2104-12-05-03-53 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p087675\p087675-2104-12-05-03-53.csv.
# All PPG data from p089565-2174-05-12-00-07 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p089565\p089565-2174-05-12-00-07.csv.
# All PPG data from p089565-2174-05-13-13-03 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p089565\p089565-2174-05-13-13-03.csv.
# All PPG data from p092289-2183-03-17-23-12 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p092289\p092289-2183-03-17-23-12.csv.
# All PPG data from p092846-2129-12-21-13-12 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p092846\p092846-2129-12-21-13-12.csv.
# All PPG data from p094847-2112-02-12-19-56 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p094847\p094847-2112-02-12-19-56.csv.
# All PPG data from p094847-2112-02-14-06-52 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p094847\p094847-2112-02-14-06-52.csv.
# All PPG data from p097547-2125-10-21-23-43 has been combined and saved to I:/mimic_dataset/csv_dataset_125hz\p097547\p097547-2125-10-21-23-43.csv.
