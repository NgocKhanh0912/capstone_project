# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, BatchNormalization, Activation, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras import Input

# Updated CNN model
def create_dilated_cnn(input_shape):
    model = Sequential()
    model.add(Input(shape=input_shape))  # Specify input shape
    model.add(Conv1D(filters=4, kernel_size=3, dilation_rate=1, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('elu'))

    # Subsequent convolutional layers with increasing dilation rates
    dilation_rates = [2, 4, 8, 16, 32, 64]
    for rate in dilation_rates:
        model.add(Conv1D(filters=32, kernel_size=3, dilation_rate=rate, padding='same'))
        model.add(BatchNormalization())
        model.add(Activation('elu'))

    # Final convolutional layer with `segment_length` filters
    model.add(Conv1D(filters=1, kernel_size=1, activation='sigmoid'))
    return model

# Prepare PPG data and labels
def process_ppg_file(file_path, label_path, segment_length=256, normalization_range=(-1, 1)):
    """
    Read PPG signals and labels from files, normalize them, and divide into segments.
    """
    # Read PPG signal
    ppg_data = pd.read_csv(file_path, header=None).squeeze("columns").values
    ppg_min, ppg_max = np.min(ppg_data), np.max(ppg_data)
    norm_min, norm_max = normalization_range
    normalized_ppg = norm_min + (ppg_data - ppg_min) * (norm_max - norm_min) / (ppg_max - ppg_min)

    peaks_indices = pd.read_csv(label_path, header=None).squeeze("columns").values
    labels, segments = [], []
    for i in range(0, len(normalized_ppg), segment_length):
        segment = normalized_ppg[i:i+segment_length]
        if len(segment) < segment_length:
            segment = np.pad(segment, (0, segment_length - len(segment)), 'constant', constant_values=0)
        segments.append(segment)
        label = np.zeros(segment_length)
        for peak in peaks_indices:
            if i <= peak < i + segment_length:
                peak_pos = peak - i
                label[max(0, peak_pos - 2):min(segment_length, peak_pos + 3)] = 1
        labels.append(label)
    return np.array(segments), np.array(labels)

# File paths
input_dir = 'E:/dilated_cnn_peak_detection_model_data/train/train_data/data'
label_dir = 'E:/dilated_cnn_peak_detection_model_data/train/train_data/label'
segment_length = 256  

# Create the model
input_shape = (segment_length, 1)
model = create_dilated_cnn(input_shape)

# Initialize optimizer with a low learning rate
initial_learning_rate = 1e-4
optimizer = Adam(learning_rate=initial_learning_rate)

# Compile the model
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Callbacks to reduce learning rate and stop early
reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, min_lr=1e-8, verbose=1)
early_stopping = EarlyStopping(monitor='loss', patience=10, verbose=1, restore_best_weights=True)

# Train the model with each file and calculate the global loss
global_loss = 0
file_count = 0

for file_name in os.listdir(input_dir):
    input_file = os.path.join(input_dir, file_name)
    label_file = os.path.join(label_dir, file_name.replace(".csv", "_labeled_peaks.csv"))
    if os.path.exists(label_file):
        print(f"Processing: {file_name}")
        ppg_segments, ppg_labels = process_ppg_file(input_file, label_file, segment_length)
        ppg_segments = np.expand_dims(ppg_segments, axis=-1)  # Reshape (samples, 256, 1)

        history = model.fit(
            ppg_segments,
            ppg_labels,
            epochs=200,  
            batch_size=32, 
            verbose=0,
            callbacks=[reduce_lr, early_stopping]
        )
        file_loss = history.history['loss'][-1]
        print(f"Loss for file {file_name}: {file_loss:.4f}")
        global_loss += file_loss
        file_count += 1

# Calculate the average global loss
global_loss /= file_count
print(f"Global loss (average across all files): {global_loss:.4f}")

# Save the trained model
model.save("../dilated_cnn_peak_detection_model.h5")
print("Training complete, and the model has been saved.")
# Out:
# Processing: golden_ppg_data_100hz.csv
# Restoring model weights from the end of the best epoch: 200.
# Loss for file golden_ppg_data_100hz.csv: 0.4546
# Processing: mimic_perform_af_001_data.csv
# Restoring model weights from the end of the best epoch: 200.
# Loss for file mimic_perform_af_001_data.csv: 0.1463
# Processing: mimic_perform_af_002_data.csv
# Restoring model weights from the end of the best epoch: 200.
# Loss for file mimic_perform_af_002_data.csv: 0.0617
# Processing: mimic_perform_af_003_data.csv
# Restoring model weights from the end of the best epoch: 200.
# Loss for file mimic_perform_af_003_data.csv: 0.0280
# Processing: mimic_perform_af_004_data.csv
#
# Epoch 56: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 64: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 70: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 79: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#
# Epoch 84: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 84: early stopping
# Restoring model weights from the end of the best epoch: 74.
# Loss for file mimic_perform_af_004_data.csv: 0.0487
# Processing: mimic_perform_af_005_data.csv
#
# Epoch 169: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
#
# Epoch 181: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
#
# Epoch 186: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-07.
#
# Epoch 196: ReduceLROnPlateau reducing learning rate to 1.9531249506599124e-07.
# Restoring model weights from the end of the best epoch: 198.
# Loss for file mimic_perform_af_005_data.csv: 0.0488
# Processing: mimic_perform_af_006_data.csv
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 9.765624753299562e-08.
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 4.882812376649781e-08.
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 2.4414061883248905e-08.
# Epoch 44: early stopping
# Restoring model weights from the end of the best epoch: 34.
# Loss for file mimic_perform_af_006_data.csv: 0.6549
# Processing: mimic_perform_af_007_data.csv
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 1.2207030941624453e-08.
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1e-08.
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_af_007_data.csv: 0.0535
# Processing: mimic_perform_af_008_data.csv
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Loss for file mimic_perform_af_008_data.csv: 0.1513
# Processing: mimic_perform_af_009_data.csv
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 19.
# Loss for file mimic_perform_af_009_data.csv: 0.0859
# Processing: mimic_perform_af_010_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_af_010_data.csv: 0.0536
# Processing: mimic_perform_af_011_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_af_011_data.csv: 0.0811
# Processing: mimic_perform_af_012_data.csv
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Loss for file mimic_perform_af_012_data.csv: 0.0665
# Processing: mimic_perform_af_013_data.csv
# Epoch 47: early stopping
# Restoring model weights from the end of the best epoch: 37.
# Loss for file mimic_perform_af_013_data.csv: 0.0610
# Processing: mimic_perform_af_014_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_af_014_data.csv: 0.1066
# Processing: mimic_perform_non_af_001_data.csv
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Loss for file mimic_perform_non_af_001_data.csv: 0.0930
# Processing: mimic_perform_non_af_002_data.csv
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Loss for file mimic_perform_non_af_002_data.csv: 0.1136
# Processing: mimic_perform_non_af_003_data.csv
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 22.
# Loss for file mimic_perform_non_af_003_data.csv: 0.0581
# Processing: mimic_perform_non_af_004_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_non_af_004_data.csv: 0.0851
# Processing: mimic_perform_non_af_005_data.csv
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 20.
# Loss for file mimic_perform_non_af_005_data.csv: 0.0815
# Processing: mimic_perform_non_af_006_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_non_af_006_data.csv: 0.0494
# Processing: mimic_perform_non_af_007_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_non_af_007_data.csv: 0.0624
# Processing: mimic_perform_non_af_008_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_non_af_008_data.csv: 0.0760
# Processing: mimic_perform_non_af_009_data.csv
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.
# Loss for file mimic_perform_non_af_009_data.csv: 0.0658
# Processing: mimic_perform_non_af_010_data.csv
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Loss for file mimic_perform_non_af_010_data.csv: 0.0442
# Processing: mimic_perform_non_af_011_data.csv
# Epoch 33: early stopping
# Restoring model weights from the end of the best epoch: 23.
# Loss for file mimic_perform_non_af_011_data.csv: 0.0765
# Processing: mimic_perform_test_all_001_data.csv
# Epoch 50: early stopping
# Restoring model weights from the end of the best epoch: 40.
# Loss for file mimic_perform_test_all_001_data.csv: 0.0977
# Processing: mimic_perform_test_all_002_data.csv
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 15.
# Loss for file mimic_perform_test_all_002_data.csv: 0.0841
# Processing: mimic_perform_test_all_003_data.csv
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 22.
# Loss for file mimic_perform_test_all_003_data.csv: 0.1213
# Processing: mimic_perform_test_all_004_data.csv
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 17.
# Loss for file mimic_perform_test_all_004_data.csv: 0.0923
# Processing: mimic_perform_test_all_005_data.csv
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Loss for file mimic_perform_test_all_005_data.csv: 0.0782
# Processing: mimic_perform_test_all_006_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_006_data.csv: 0.0715
# Processing: mimic_perform_test_all_007_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_007_data.csv: 0.4798
# Processing: mimic_perform_test_all_008_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_008_data.csv: 0.0819
# Processing: mimic_perform_test_all_009_data.csv
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Loss for file mimic_perform_test_all_009_data.csv: 0.0922
# Processing: mimic_perform_test_all_010_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_010_data.csv: 0.1114
# Processing: mimic_perform_test_all_011_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_011_data.csv: 0.2959
# Processing: mimic_perform_test_all_012_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_012_data.csv: 0.1333
# Processing: mimic_perform_test_all_013_data.csv
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Loss for file mimic_perform_test_all_013_data.csv: 0.0589
# Processing: mimic_perform_test_all_014_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_014_data.csv: 0.1796
# Processing: mimic_perform_test_all_015_data.csv
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Loss for file mimic_perform_test_all_015_data.csv: 0.3669
# Processing: mimic_perform_test_all_016_data.csv
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 17.
# Loss for file mimic_perform_test_all_016_data.csv: 0.2206
# Processing: mimic_perform_test_all_017_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_test_all_017_data.csv: 0.0833
# Processing: mimic_perform_test_all_018_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_018_data.csv: 0.0665
# Processing: mimic_perform_test_all_019_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_019_data.csv: 0.0989
# Processing: mimic_perform_test_all_020_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_020_data.csv: 0.3965
# Processing: mimic_perform_test_all_021_data.csv
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 15.
# Loss for file mimic_perform_test_all_021_data.csv: 0.1141
# Processing: mimic_perform_test_all_022_data.csv
# Epoch 40: early stopping
# Restoring model weights from the end of the best epoch: 30.
# Loss for file mimic_perform_test_all_022_data.csv: 0.0450
# Processing: mimic_perform_test_all_023_data.csv
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Loss for file mimic_perform_test_all_023_data.csv: 0.0581
# Processing: mimic_perform_test_all_024_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_024_data.csv: 0.0514
# Processing: mimic_perform_test_all_025_data.csv
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.
# Loss for file mimic_perform_test_all_025_data.csv: 0.1165
# Processing: mimic_perform_test_all_026_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_026_data.csv: 0.0744
# Processing: mimic_perform_test_all_027_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_027_data.csv: 0.0865
# Processing: mimic_perform_test_all_028_data.csv
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 17.
# Loss for file mimic_perform_test_all_028_data.csv: 0.0907
# Processing: mimic_perform_test_all_029_data.csv
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Loss for file mimic_perform_test_all_029_data.csv: 0.0787
# Processing: mimic_perform_test_all_030_data.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file mimic_perform_test_all_030_data.csv: 0.4484
# Processing: mimic_perform_test_all_031_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_test_all_031_data.csv: 0.0902
# Processing: mimic_perform_test_all_032_data.csv
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Loss for file mimic_perform_test_all_032_data.csv: 0.0691
# Processing: mimic_perform_test_all_033_data.csv
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Loss for file mimic_perform_test_all_033_data.csv: 0.1113
# Processing: mimic_perform_test_all_034_data.csv
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Loss for file mimic_perform_test_all_034_data.csv: 0.1767
# Processing: mimic_perform_test_all_035_data.csv
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 19.
# Loss for file mimic_perform_test_all_035_data.csv: 0.0881
# Processing: mimic_perform_test_all_036_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_036_data.csv: 0.1164
# Processing: mimic_perform_test_all_037_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_037_data.csv: 0.5111
# Processing: mimic_perform_test_all_038_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_038_data.csv: 0.0841
# Processing: mimic_perform_test_all_039_data.csv
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Loss for file mimic_perform_test_all_039_data.csv: 0.1137
# Processing: mimic_perform_test_all_040_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_040_data.csv: 0.0813
# Processing: mimic_perform_test_all_041_data.csv
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 18.
# Loss for file mimic_perform_test_all_041_data.csv: 0.1068
# Processing: mimic_perform_test_all_042_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_042_data.csv: 0.0837
# Processing: mimic_perform_test_all_043_data.csv
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 17.
# Loss for file mimic_perform_test_all_043_data.csv: 0.0882
# Processing: mimic_perform_test_all_044_data.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file mimic_perform_test_all_044_data.csv: 0.2560
# Processing: mimic_perform_test_all_045_data.csv
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Loss for file mimic_perform_test_all_045_data.csv: 0.0788
# Processing: mimic_perform_test_all_046_data.csv
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Loss for file mimic_perform_test_all_046_data.csv: 0.0946
# Processing: mimic_perform_test_all_047_data.csv
# Epoch 38: early stopping
# Restoring model weights from the end of the best epoch: 28.
# Loss for file mimic_perform_test_all_047_data.csv: 0.1886
# Processing: mimic_perform_test_all_048_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_test_all_048_data.csv: 0.0419
# Processing: mimic_perform_test_all_049_data.csv
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Loss for file mimic_perform_test_all_049_data.csv: 0.0639
# Processing: mimic_perform_test_all_050_data.csv
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Loss for file mimic_perform_test_all_050_data.csv: 0.0983
# Processing: mimic_perform_test_all_051_data.csv
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 17.
# Loss for file mimic_perform_test_all_051_data.csv: 0.0536
# Processing: mimic_perform_test_all_052_data.csv
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Loss for file mimic_perform_test_all_052_data.csv: 0.4611
# Processing: mimic_perform_test_all_053_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_053_data.csv: 0.0595
# Processing: mimic_perform_test_all_054_data.csv
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Loss for file mimic_perform_test_all_054_data.csv: 0.0625
# Processing: mimic_perform_test_all_055_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_055_data.csv: 0.0691
# Processing: mimic_perform_test_all_056_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_056_data.csv: 0.0616
# Processing: mimic_perform_test_all_057_data.csv
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Loss for file mimic_perform_test_all_057_data.csv: 0.0991
# Processing: mimic_perform_test_all_058_data.csv
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 16.
# Loss for file mimic_perform_test_all_058_data.csv: 0.7150
# Processing: mimic_perform_test_all_059_data.csv
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 17.
# Loss for file mimic_perform_test_all_059_data.csv: 0.3476
# Processing: mimic_perform_test_all_060_data.csv
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 18.
# Loss for file mimic_perform_test_all_060_data.csv: 0.0762
# Processing: mimic_perform_test_all_061_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_061_data.csv: 0.0847
# Processing: mimic_perform_test_all_062_data.csv
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Loss for file mimic_perform_test_all_062_data.csv: 0.0719
# Processing: mimic_perform_test_all_063_data.csv
# Epoch 31: early stopping
# Restoring model weights from the end of the best epoch: 21.
# Loss for file mimic_perform_test_all_063_data.csv: 0.0755
# Processing: mimic_perform_test_all_064_data.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file mimic_perform_test_all_064_data.csv: 0.1081
# Processing: mimic_perform_test_all_065_data.csv
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Loss for file mimic_perform_test_all_065_data.csv: 0.1353
# Processing: mimic_perform_test_all_066_data.csv
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Loss for file mimic_perform_test_all_066_data.csv: 0.0640
# Processing: mimic_perform_test_all_067_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_067_data.csv: 0.2062
# Processing: mimic_perform_test_all_068_data.csv
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Loss for file mimic_perform_test_all_068_data.csv: 0.1168
# Processing: mimic_perform_test_all_069_data.csv
# Epoch 33: early stopping
# Restoring model weights from the end of the best epoch: 23.
# Loss for file mimic_perform_test_all_069_data.csv: 0.5234
# Processing: mimic_perform_test_all_070_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_070_data.csv: 0.0393
# Processing: mimic_perform_test_all_071_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_071_data.csv: 0.0969
# Processing: mimic_perform_test_all_072_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_072_data.csv: 0.0899
# Processing: mimic_perform_test_all_073_data.csv
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Loss for file mimic_perform_test_all_073_data.csv: 0.0889
# Processing: mimic_perform_test_all_074_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_074_data.csv: 0.0536
# Processing: mimic_perform_test_all_075_data.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file mimic_perform_test_all_075_data.csv: 0.0588
# Processing: mimic_perform_test_all_076_data.csv
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 18.
# Loss for file mimic_perform_test_all_076_data.csv: 0.0729
# Processing: mimic_perform_test_all_077_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_077_data.csv: 0.2881
# Processing: mimic_perform_test_all_078_data.csv
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 16.
# Loss for file mimic_perform_test_all_078_data.csv: 0.1172
# Processing: mimic_perform_test_all_079_data.csv
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 22.
# Loss for file mimic_perform_test_all_079_data.csv: 0.0892
# Processing: mimic_perform_test_all_080_data.csv
# Epoch 36: early stopping
# Restoring model weights from the end of the best epoch: 26.
# Loss for file mimic_perform_test_all_080_data.csv: 0.1390
# Processing: mimic_perform_test_all_081_data.csv
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Loss for file mimic_perform_test_all_081_data.csv: 0.0720
# Processing: mimic_perform_test_all_082_data.csv
# Epoch 31: early stopping
# Restoring model weights from the end of the best epoch: 21.
# Loss for file mimic_perform_test_all_082_data.csv: 0.0801
# Processing: mimic_perform_test_all_083_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_083_data.csv: 0.1252
# Processing: mimic_perform_test_all_084_data.csv
# Epoch 33: early stopping
# Restoring model weights from the end of the best epoch: 23.
# Loss for file mimic_perform_test_all_084_data.csv: 0.0617
# Processing: mimic_perform_test_all_085_data.csv
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 15.
# Loss for file mimic_perform_test_all_085_data.csv: 0.0841
# Processing: mimic_perform_test_all_086_data.csv
# Epoch 40: early stopping
# Restoring model weights from the end of the best epoch: 30.
# Loss for file mimic_perform_test_all_086_data.csv: 0.0584
# Processing: mimic_perform_test_all_087_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_087_data.csv: 0.1079
# Processing: mimic_perform_test_all_088_data.csv
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Loss for file mimic_perform_test_all_088_data.csv: 0.0472
# Processing: mimic_perform_test_all_089_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_089_data.csv: 0.0887
# Processing: mimic_perform_test_all_090_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_090_data.csv: 0.0834
# Processing: mimic_perform_test_all_091_data.csv
# Epoch 34: early stopping
# Restoring model weights from the end of the best epoch: 24.
# Loss for file mimic_perform_test_all_091_data.csv: 0.0839
# Processing: mimic_perform_test_all_092_data.csv
# Epoch 33: early stopping
# Restoring model weights from the end of the best epoch: 23.
# Loss for file mimic_perform_test_all_092_data.csv: 0.1141
# Processing: mimic_perform_test_all_093_data.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file mimic_perform_test_all_093_data.csv: 0.1013
# Processing: mimic_perform_test_all_094_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_094_data.csv: 0.0540
# Processing: mimic_perform_test_all_095_data.csv
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Loss for file mimic_perform_test_all_095_data.csv: 0.0892
# Processing: mimic_perform_test_all_096_data.csv
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Loss for file mimic_perform_test_all_096_data.csv: 0.7333
# Processing: mimic_perform_test_all_097_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_097_data.csv: 0.0882
# Processing: mimic_perform_test_all_098_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_098_data.csv: 0.0651
# Processing: mimic_perform_test_all_099_data.csv
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Loss for file mimic_perform_test_all_099_data.csv: 0.0758
# Processing: mimic_perform_test_all_100_data.csv
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Loss for file mimic_perform_test_all_100_data.csv: 0.0881
# Processing: mimic_perform_test_all_101_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_101_data.csv: 0.2306
# Processing: mimic_perform_test_all_102_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_102_data.csv: 0.0888
# Processing: mimic_perform_test_all_103_data.csv
# Epoch 31: early stopping
# Restoring model weights from the end of the best epoch: 21.
# Loss for file mimic_perform_test_all_103_data.csv: 0.0764
# Processing: mimic_perform_test_all_104_data.csv
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 18.
# Loss for file mimic_perform_test_all_104_data.csv: 0.1311
# Processing: mimic_perform_test_all_105_data.csv
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Loss for file mimic_perform_test_all_105_data.csv: 0.1003
# Processing: mimic_perform_test_all_106_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_106_data.csv: 0.1011
# Processing: mimic_perform_test_all_107_data.csv
# Epoch 33: early stopping
# Restoring model weights from the end of the best epoch: 23.
# Loss for file mimic_perform_test_all_107_data.csv: 0.1960
# Processing: mimic_perform_test_all_108_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_test_all_108_data.csv: 0.1010
# Processing: mimic_perform_test_all_109_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_109_data.csv: 0.1380
# Processing: mimic_perform_test_all_110_data.csv
# Epoch 39: early stopping
# Restoring model weights from the end of the best epoch: 29.
# Loss for file mimic_perform_test_all_110_data.csv: 0.1502
# Processing: mimic_perform_test_all_111_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_111_data.csv: 0.2260
# Processing: mimic_perform_test_all_112_data.csv
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Loss for file mimic_perform_test_all_112_data.csv: 0.1898
# Processing: mimic_perform_test_all_113_data.csv
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 17.
# Loss for file mimic_perform_test_all_113_data.csv: 0.2564
# Processing: mimic_perform_test_all_114_data.csv
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 18.
# Loss for file mimic_perform_test_all_114_data.csv: 0.1542
# Processing: mimic_perform_test_all_115_data.csv
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 17.
# Loss for file mimic_perform_test_all_115_data.csv: 0.1578
# Processing: mimic_perform_test_all_116_data.csv
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Loss for file mimic_perform_test_all_116_data.csv: 0.2220
# Processing: mimic_perform_test_all_117_data.csv
# Epoch 33: early stopping
# Restoring model weights from the end of the best epoch: 23.
# Loss for file mimic_perform_test_all_117_data.csv: 0.1287
# Processing: mimic_perform_test_all_118_data.csv
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 22.
# Loss for file mimic_perform_test_all_118_data.csv: 0.2037
# Processing: mimic_perform_test_all_119_data.csv
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.
# Loss for file mimic_perform_test_all_119_data.csv: 0.1270
# Processing: mimic_perform_test_all_120_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_120_data.csv: 0.1022
# Processing: mimic_perform_test_all_121_data.csv
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.
# Loss for file mimic_perform_test_all_121_data.csv: 0.1124
# Processing: mimic_perform_test_all_122_data.csv
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Loss for file mimic_perform_test_all_122_data.csv: 0.1064
# Processing: mimic_perform_test_all_123_data.csv
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Loss for file mimic_perform_test_all_123_data.csv: 0.1930
# Processing: mimic_perform_test_all_124_data.csv
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Loss for file mimic_perform_test_all_124_data.csv: 0.1487
# Processing: mimic_perform_test_all_125_data.csv
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Loss for file mimic_perform_test_all_125_data.csv: 0.1355
# Processing: mimic_perform_test_all_126_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_126_data.csv: 0.1643
# Processing: mimic_perform_test_all_127_data.csv
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Loss for file mimic_perform_test_all_127_data.csv: 0.1464
# Processing: mimic_perform_test_all_128_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_test_all_128_data.csv: 0.1237
# Processing: mimic_perform_test_all_129_data.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file mimic_perform_test_all_129_data.csv: 0.1083
# Processing: mimic_perform_test_all_130_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_130_data.csv: 0.2980
# Processing: mimic_perform_test_all_131_data.csv
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 16.
# Loss for file mimic_perform_test_all_131_data.csv: 0.4579
# Processing: mimic_perform_test_all_132_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_132_data.csv: 0.3001
# Processing: mimic_perform_test_all_133_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_133_data.csv: 0.1576
# Processing: mimic_perform_test_all_134_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_test_all_134_data.csv: 0.1840
# Processing: mimic_perform_test_all_135_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_135_data.csv: 0.2450
# Processing: mimic_perform_test_all_136_data.csv
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 19.
# Loss for file mimic_perform_test_all_136_data.csv: 0.1405
# Processing: mimic_perform_test_all_137_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_137_data.csv: 0.0865
# Processing: mimic_perform_test_all_138_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_138_data.csv: 0.0670
# Processing: mimic_perform_test_all_139_data.csv
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Loss for file mimic_perform_test_all_139_data.csv: 0.0793
# Processing: mimic_perform_test_all_140_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_test_all_140_data.csv: 0.1696
# Processing: mimic_perform_test_all_141_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_141_data.csv: 0.1527
# Processing: mimic_perform_test_all_142_data.csv
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Loss for file mimic_perform_test_all_142_data.csv: 0.1306
# Processing: mimic_perform_test_all_143_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_143_data.csv: 0.1931
# Processing: mimic_perform_test_all_144_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_144_data.csv: 0.0932
# Processing: mimic_perform_test_all_145_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_145_data.csv: 0.1653
# Processing: mimic_perform_test_all_146_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_test_all_146_data.csv: 0.1487
# Processing: mimic_perform_test_all_147_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_147_data.csv: 0.0792
# Processing: mimic_perform_test_all_148_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_test_all_148_data.csv: 0.1218
# Processing: mimic_perform_test_all_149_data.csv
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Loss for file mimic_perform_test_all_149_data.csv: 0.2059
# Processing: mimic_perform_test_all_150_data.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file mimic_perform_test_all_150_data.csv: 0.1397
# Processing: mimic_perform_test_all_151_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_151_data.csv: 0.2137
# Processing: mimic_perform_test_all_152_data.csv
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Loss for file mimic_perform_test_all_152_data.csv: 0.1866
# Processing: mimic_perform_test_all_153_data.csv
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Loss for file mimic_perform_test_all_153_data.csv: 0.1456
# Processing: mimic_perform_test_all_154_data.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file mimic_perform_test_all_154_data.csv: 0.1412
# Processing: mimic_perform_test_all_155_data.csv
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Loss for file mimic_perform_test_all_155_data.csv: 0.1357
# Processing: mimic_perform_test_all_156_data.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file mimic_perform_test_all_156_data.csv: 0.0904
# Processing: mimic_perform_test_all_157_data.csv
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.
# Loss for file mimic_perform_test_all_157_data.csv: 0.1268
# Processing: mimic_perform_test_all_158_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_158_data.csv: 0.1491
# Processing: mimic_perform_test_all_159_data.csv
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Loss for file mimic_perform_test_all_159_data.csv: 0.1698
# Processing: mimic_perform_test_all_160_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_160_data.csv: 0.1769
# Processing: mimic_perform_test_all_161_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_test_all_161_data.csv: 0.1599
# Processing: mimic_perform_test_all_162_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_162_data.csv: 0.1094
# Processing: mimic_perform_test_all_163_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_163_data.csv: 0.1657
# Processing: mimic_perform_test_all_164_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_164_data.csv: 0.1805
# Processing: mimic_perform_test_all_165_data.csv
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Loss for file mimic_perform_test_all_165_data.csv: 0.2047
# Processing: mimic_perform_test_all_166_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_test_all_166_data.csv: 0.1411
# Processing: mimic_perform_test_all_167_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_167_data.csv: 0.2314
# Processing: mimic_perform_test_all_168_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_168_data.csv: 0.1573
# Processing: mimic_perform_test_all_169_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_169_data.csv: 0.1701
# Processing: mimic_perform_test_all_170_data.csv
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 15.
# Loss for file mimic_perform_test_all_170_data.csv: 0.0991
# Processing: mimic_perform_test_all_171_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_171_data.csv: 0.1444
# Processing: mimic_perform_test_all_172_data.csv
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.
# Loss for file mimic_perform_test_all_172_data.csv: 0.1406
# Processing: mimic_perform_test_all_173_data.csv
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Loss for file mimic_perform_test_all_173_data.csv: 0.2157
# Processing: mimic_perform_test_all_174_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_174_data.csv: 0.1591
# Processing: mimic_perform_test_all_175_data.csv
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Loss for file mimic_perform_test_all_175_data.csv: 0.0915
# Processing: mimic_perform_test_all_176_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_test_all_176_data.csv: 0.1170
# Processing: mimic_perform_test_all_177_data.csv
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Loss for file mimic_perform_test_all_177_data.csv: 0.1350
# Processing: mimic_perform_test_all_178_data.csv
# Epoch 39: early stopping
# Restoring model weights from the end of the best epoch: 29.
# Loss for file mimic_perform_test_all_178_data.csv: 0.1947
# Processing: mimic_perform_test_all_179_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_179_data.csv: 0.2269
# Processing: mimic_perform_test_all_180_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_180_data.csv: 0.1878
# Processing: mimic_perform_test_all_181_data.csv
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Loss for file mimic_perform_test_all_181_data.csv: 0.3724
# Processing: mimic_perform_test_all_182_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_182_data.csv: 0.1565
# Processing: mimic_perform_test_all_183_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_183_data.csv: 0.1544
# Processing: mimic_perform_test_all_184_data.csv
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Loss for file mimic_perform_test_all_184_data.csv: 0.2565
# Processing: mimic_perform_test_all_185_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_185_data.csv: 0.0883
# Processing: mimic_perform_test_all_186_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_186_data.csv: 0.2105
# Processing: mimic_perform_test_all_187_data.csv
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Loss for file mimic_perform_test_all_187_data.csv: 0.0861
# Processing: mimic_perform_test_all_188_data.csv
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 20.
# Loss for file mimic_perform_test_all_188_data.csv: 0.1911
# Processing: mimic_perform_test_all_189_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_189_data.csv: 0.2365
# Processing: mimic_perform_test_all_190_data.csv
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 22.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Loss for file mimic_perform_test_all_190_data.csv: 0.1803
# Global loss (average across all files): 0.1449
# Training complete, and the model has been saved.
