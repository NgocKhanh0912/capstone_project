# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, BatchNormalization, Activation, Flatten, Dense, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
import sys
sys.path.append("../../common_tools/signal_processing")
from normalize_signal import normalize_ppg

def create_dilated_cnn(input_shape):
    model = Sequential()
    model.add(Input(shape=input_shape, name="input_layer"))
    model.add(Conv1D(filters=4, kernel_size=3, dilation_rate=1, padding='same', name="conv1"))
    model.add(BatchNormalization(name="batchnorm1"))
    model.add(Activation('elu', name="activation1"))

    dilation_rates = [2, 4, 8, 16, 32, 64]
    for idx, rate in enumerate(dilation_rates):
        model.add(Conv1D(filters=32, kernel_size=3, dilation_rate=rate, padding='same', name=f"conv{idx+2}"))
        model.add(BatchNormalization(name=f"batchnorm{idx+2}"))
        model.add(Activation('elu', name=f"activation{idx+2}"))

    model.add(Conv1D(filters=1, kernel_size=1, activation='sigmoid', name="output_layer"))
    return model

# Prepare PPG data and labels
def process_ppg_file(file_path, label_path, segment_length=256):
    """
    Read PPG signals and labels from files, normalize them, and divide into segments.
    """
    # Read PPG signal
    ppg_data = pd.read_csv(file_path, header=None).squeeze("columns").values
    normalized_ppg = normalize_ppg(ppg_data)

    peaks_indices = pd.read_csv(label_path, header=None).squeeze("columns").values
    labels, segments = [], []
    for i in range(0, len(normalized_ppg), segment_length):
        segment = normalized_ppg[i:i+segment_length]
        if len(segment) < segment_length:
            segment = np.pad(segment, (0, segment_length - len(segment)), 'constant', constant_values=0)
        segments.append(segment)
        label = np.zeros(segment_length)
        for peak in peaks_indices:
            if i <= peak < i + segment_length:
                peak_pos = peak - i
                label[max(0, peak_pos - 2):min(segment_length, peak_pos + 3)] = 1
        labels.append(label)
    return np.array(segments), np.array(labels)

# File paths
input_dir = 'E:/dilated_cnn_peak_detection_model_data/train/train_data/data'
label_dir = 'E:/dilated_cnn_peak_detection_model_data/train/train_data/label'
segment_length = 256  

# Create the model
input_shape = (segment_length, 1)
model = create_dilated_cnn(input_shape)

# Initialize optimizer with a low learning rate
initial_learning_rate = 1e-4
optimizer = Adam(learning_rate=initial_learning_rate)

# Compile the model
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Callbacks to reduce learning rate and stop early
reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, min_lr=1e-8, verbose=1)
early_stopping = EarlyStopping(monitor='loss', patience=10, verbose=1, restore_best_weights=True)

# Train the model with each file and calculate the global loss
global_loss = 0
file_count = 0

for file_name in os.listdir(input_dir):
    input_file = os.path.join(input_dir, file_name)
    label_file = os.path.join(label_dir, file_name.replace(".csv", "_labeled_peaks.csv"))
    if os.path.exists(label_file):
        print(f"Processing: {file_name}")
        ppg_segments, ppg_labels = process_ppg_file(input_file, label_file, segment_length)
        ppg_segments = np.expand_dims(ppg_segments, axis=-1)

        history = model.fit(
            ppg_segments,
            ppg_labels,
            epochs=200,  
            batch_size=32, 
            verbose=0,
            callbacks=[reduce_lr, early_stopping]
        )
        file_loss = history.history['loss'][-1]
        print(f"Loss for file {file_name}: {file_loss:.4f}")
        global_loss += file_loss
        file_count += 1

# Calculate the average global loss
global_loss /= file_count
print(f"Global loss (average across all files): {global_loss:.4f}")

# Save the trained model
model.save("../dilated_cnn_peak_detection_model.h5", include_optimizer=False)
print("Training complete, and the model has been saved.")
# Out:
# Processing: mimic_perform_af_004_data.csv
# Restoring model weights from the end of the best epoch: 200.
# Loss for file mimic_perform_af_004_data.csv: 0.0408
# Processing: mimic_perform_af_005_data.csv
#
# Epoch 87: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 101: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 110: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 118: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#
# Epoch 123: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 123: early stopping
# Restoring model weights from the end of the best epoch: 113.
# Loss for file mimic_perform_af_005_data.csv: 0.0161
# Processing: mimic_perform_af_006_data.csv
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
#
# Epoch 57: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
#
# Epoch 62: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-07.
# Epoch 62: early stopping
# Restoring model weights from the end of the best epoch: 52.
# Loss for file mimic_perform_af_006_data.csv: 0.0904
# Processing: mimic_perform_af_007_data.csv
#
# Epoch 78: ReduceLROnPlateau reducing learning rate to 1.9531249506599124e-07.
#
# Epoch 83: ReduceLROnPlateau reducing learning rate to 9.765624753299562e-08.
#
# Epoch 94: ReduceLROnPlateau reducing learning rate to 4.882812376649781e-08.
#
# Epoch 99: ReduceLROnPlateau reducing learning rate to 2.4414061883248905e-08.
# Epoch 99: early stopping
# Restoring model weights from the end of the best epoch: 89.
# Loss for file mimic_perform_af_007_data.csv: 0.0292
# Processing: mimic_perform_af_008_data.csv
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1.2207030941624453e-08.
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1e-08.
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Loss for file mimic_perform_af_008_data.csv: 0.0669
# Processing: mimic_perform_af_009_data.csv
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Loss for file mimic_perform_af_009_data.csv: 0.0742
# Processing: mimic_perform_af_010_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_af_010_data.csv: 0.0358
# Processing: mimic_perform_af_011_data.csv
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.
# Loss for file mimic_perform_af_011_data.csv: 0.0457
# Processing: mimic_perform_af_012_data.csv
# Epoch 36: early stopping
# Restoring model weights from the end of the best epoch: 26.
# Loss for file mimic_perform_af_012_data.csv: 0.0607
# Processing: mimic_perform_af_013_data.csv
# Epoch 33: early stopping
# Restoring model weights from the end of the best epoch: 23.
# Loss for file mimic_perform_af_013_data.csv: 0.0400
# Processing: mimic_perform_af_014_data.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file mimic_perform_af_014_data.csv: 0.0379
# Processing: mimic_perform_af_015_data.csv
# Epoch 42: early stopping
# Restoring model weights from the end of the best epoch: 32.
# Loss for file mimic_perform_af_015_data.csv: 0.0184
# Processing: mimic_perform_af_016_data.csv
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 19.
# Loss for file mimic_perform_af_016_data.csv: 0.0590
# Processing: mimic_perform_af_017_data.csv
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Loss for file mimic_perform_af_017_data.csv: 0.0433
# Processing: mimic_perform_af_018_data.csv
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Loss for file mimic_perform_af_018_data.csv: 0.0475
# Processing: mimic_perform_af_019_data.csv
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Loss for file mimic_perform_af_019_data.csv: 0.0399
# Processing: mimic_perform_non_af_004_data.csv
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Loss for file mimic_perform_non_af_004_data.csv: 0.0628
# Processing: mimic_perform_non_af_005_data.csv
# Epoch 114: early stopping
# Restoring model weights from the end of the best epoch: 104.
# Loss for file mimic_perform_non_af_005_data.csv: 0.0292
# Processing: mimic_perform_non_af_006_data.csv
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 17.
# Loss for file mimic_perform_non_af_006_data.csv: 0.0230
# Processing: mimic_perform_non_af_007_data.csv
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Loss for file mimic_perform_non_af_007_data.csv: 0.0279
# Processing: mimic_perform_non_af_008_data.csv
# Restoring model weights from the end of the best epoch: 194.
# Loss for file mimic_perform_non_af_008_data.csv: 0.0325
# Processing: mimic_perform_non_af_009_data.csv
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 17.
# Loss for file mimic_perform_non_af_009_data.csv: 0.0176
# Processing: mimic_perform_non_af_010_data.csv
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Loss for file mimic_perform_non_af_010_data.csv: 0.0270
# Processing: mimic_perform_non_af_011_data.csv
# Restoring model weights from the end of the best epoch: 196.
# Loss for file mimic_perform_non_af_011_data.csv: 0.0213
# Processing: mimic_perform_non_af_012_data.csv
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Loss for file mimic_perform_non_af_012_data.csv: 0.1035
# Processing: mimic_perform_non_af_013_data.csv
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Loss for file mimic_perform_non_af_013_data.csv: 0.0227
# Processing: mimic_perform_non_af_014_data.csv
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Loss for file mimic_perform_non_af_014_data.csv: 0.5045
# Processing: mimic_perform_non_af_015_data.csv
# Epoch 41: early stopping
# Restoring model weights from the end of the best epoch: 31.
# Loss for file mimic_perform_non_af_015_data.csv: 0.0300
# Processing: mimic_perform_non_af_016_data.csv
# Epoch 31: early stopping
# Restoring model weights from the end of the best epoch: 21.
# Loss for file mimic_perform_non_af_016_data.csv: 0.0211
# Processing: mimic_perform_test_all_004_data.csv
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Loss for file mimic_perform_test_all_004_data.csv: 0.0408
# Processing: mimic_perform_test_all_005_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_005_data.csv: 0.0283
# Processing: mimic_perform_test_all_006_data.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file mimic_perform_test_all_006_data.csv: 0.0293
# Processing: mimic_perform_test_all_007_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_007_data.csv: 0.1448
# Processing: mimic_perform_test_all_008_data.csv
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Loss for file mimic_perform_test_all_008_data.csv: 0.0234
# Processing: mimic_perform_test_all_009_data.csv
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Loss for file mimic_perform_test_all_009_data.csv: 0.0575
# Processing: mimic_perform_test_all_010_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_010_data.csv: 0.0590
# Processing: mimic_perform_test_all_011_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_test_all_011_data.csv: 0.1705
# Processing: mimic_perform_test_all_012_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_012_data.csv: 0.0681
# Processing: mimic_perform_test_all_013_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_test_all_013_data.csv: 0.0236
# Processing: mimic_perform_test_all_014_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_014_data.csv: 0.0918
# Processing: mimic_perform_test_all_015_data.csv
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Loss for file mimic_perform_test_all_015_data.csv: 0.1001
# Processing: mimic_perform_test_all_016_data.csv
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Loss for file mimic_perform_test_all_016_data.csv: 0.0826
# Processing: mimic_perform_test_all_017_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_017_data.csv: 0.0392
# Processing: mimic_perform_test_all_018_data.csv
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Loss for file mimic_perform_test_all_018_data.csv: 0.0208
# Processing: mimic_perform_test_all_019_data.csv
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 17.
# Loss for file mimic_perform_test_all_019_data.csv: 0.0410
# Processing: mimic_perform_test_all_020_data.csv
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 15.
# Loss for file mimic_perform_test_all_020_data.csv: 0.1947
# Processing: mimic_perform_test_all_021_data.csv
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 20.
# Loss for file mimic_perform_test_all_021_data.csv: 0.0853
# Processing: mimic_perform_test_all_022_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_022_data.csv: 0.0339
# Processing: mimic_perform_test_all_023_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_023_data.csv: 0.0278
# Processing: mimic_perform_test_all_024_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_test_all_024_data.csv: 0.0201
# Processing: mimic_perform_test_all_025_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_025_data.csv: 0.0696
# Processing: mimic_perform_test_all_026_data.csv
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Loss for file mimic_perform_test_all_026_data.csv: 0.0250
# Processing: mimic_perform_test_all_027_data.csv
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Loss for file mimic_perform_test_all_027_data.csv: 0.0580
# Processing: mimic_perform_test_all_028_data.csv
# Epoch 46: early stopping
# Restoring model weights from the end of the best epoch: 36.
# Loss for file mimic_perform_test_all_028_data.csv: 0.0215
# Processing: mimic_perform_test_all_029_data.csv
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Loss for file mimic_perform_test_all_029_data.csv: 0.0221
# Processing: mimic_perform_test_all_030_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_030_data.csv: 0.1721
# Processing: mimic_perform_test_all_031_data.csv
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Loss for file mimic_perform_test_all_031_data.csv: 0.0307
# Processing: mimic_perform_test_all_032_data.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file mimic_perform_test_all_032_data.csv: 0.0255
# Processing: mimic_perform_test_all_033_data.csv
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 22.
# Loss for file mimic_perform_test_all_033_data.csv: 0.0676
# Processing: mimic_perform_test_all_034_data.csv
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Loss for file mimic_perform_test_all_034_data.csv: 0.0766
# Processing: mimic_perform_test_all_035_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_035_data.csv: 0.0652
# Processing: mimic_perform_test_all_036_data.csv
# Epoch 38: early stopping
# Restoring model weights from the end of the best epoch: 28.
# Loss for file mimic_perform_test_all_036_data.csv: 0.0899
# Processing: mimic_perform_test_all_037_data.csv
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 20.
# Loss for file mimic_perform_test_all_037_data.csv: 0.1812
# Processing: mimic_perform_test_all_038_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_038_data.csv: 0.0372
# Processing: mimic_perform_test_all_039_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_039_data.csv: 0.0175
# Processing: mimic_perform_test_all_040_data.csv
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Loss for file mimic_perform_test_all_040_data.csv: 0.0478
# Processing: mimic_perform_test_all_041_data.csv
# Epoch 35: early stopping
# Restoring model weights from the end of the best epoch: 25.
# Loss for file mimic_perform_test_all_041_data.csv: 0.0849
# Processing: mimic_perform_test_all_042_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_042_data.csv: 0.0532
# Processing: mimic_perform_test_all_043_data.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file mimic_perform_test_all_043_data.csv: 0.0318
# Processing: mimic_perform_test_all_044_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_044_data.csv: 0.0994
# Processing: mimic_perform_test_all_045_data.csv
# Epoch 31: early stopping
# Restoring model weights from the end of the best epoch: 21.
# Loss for file mimic_perform_test_all_045_data.csv: 0.0425
# Processing: mimic_perform_test_all_046_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_046_data.csv: 0.0436
# Processing: mimic_perform_test_all_047_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_047_data.csv: 0.1506
# Processing: mimic_perform_test_all_048_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_048_data.csv: 0.0254
# Processing: mimic_perform_test_all_049_data.csv
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Loss for file mimic_perform_test_all_049_data.csv: 0.0459
# Processing: mimic_perform_test_all_050_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_050_data.csv: 0.0317
# Processing: mimic_perform_test_all_051_data.csv
# Epoch 34: early stopping
# Restoring model weights from the end of the best epoch: 24.
# Loss for file mimic_perform_test_all_051_data.csv: 0.0291
# Processing: mimic_perform_test_all_052_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_052_data.csv: 0.1431
# Processing: mimic_perform_test_all_053_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_053_data.csv: 0.0280
# Processing: mimic_perform_test_all_054_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_054_data.csv: 0.0328
# Processing: mimic_perform_test_all_055_data.csv
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 18.
# Loss for file mimic_perform_test_all_055_data.csv: 0.0218
# Processing: mimic_perform_test_all_056_data.csv
# Epoch 31: early stopping
# Restoring model weights from the end of the best epoch: 21.
# Loss for file mimic_perform_test_all_056_data.csv: 0.0258
# Processing: mimic_perform_test_all_057_data.csv
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 22.
# Loss for file mimic_perform_test_all_057_data.csv: 0.0664
# Processing: mimic_perform_test_all_058_data.csv
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Loss for file mimic_perform_test_all_058_data.csv: 0.2662
# Processing: mimic_perform_test_all_059_data.csv
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Loss for file mimic_perform_test_all_059_data.csv: 0.0891
# Processing: mimic_perform_test_all_060_data.csv
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Loss for file mimic_perform_test_all_060_data.csv: 0.0406
# Processing: mimic_perform_test_all_061_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_061_data.csv: 0.0594
# Processing: mimic_perform_test_all_062_data.csv
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.
# Loss for file mimic_perform_test_all_062_data.csv: 0.0185
# Processing: mimic_perform_test_all_063_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_063_data.csv: 0.0494
# Processing: mimic_perform_test_all_064_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_064_data.csv: 0.0437
# Processing: mimic_perform_test_all_065_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_065_data.csv: 0.0390
# Processing: mimic_perform_test_all_066_data.csv
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Loss for file mimic_perform_test_all_066_data.csv: 0.0372
# Processing: mimic_perform_test_all_067_data.csv
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Loss for file mimic_perform_test_all_067_data.csv: 0.0801
# Processing: mimic_perform_test_all_068_data.csv
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Loss for file mimic_perform_test_all_068_data.csv: 0.0655
# Processing: mimic_perform_test_all_069_data.csv
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.
# Loss for file mimic_perform_test_all_069_data.csv: 0.1226
# Processing: mimic_perform_test_all_070_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_070_data.csv: 0.0240
# Processing: mimic_perform_test_all_071_data.csv
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Loss for file mimic_perform_test_all_071_data.csv: 0.0402
# Processing: mimic_perform_test_all_072_data.csv
# Epoch 31: early stopping
# Restoring model weights from the end of the best epoch: 21.
# Loss for file mimic_perform_test_all_072_data.csv: 0.0277
# Processing: mimic_perform_test_all_073_data.csv
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Loss for file mimic_perform_test_all_073_data.csv: 0.0605
# Processing: mimic_perform_test_all_074_data.csv
# Epoch 57: early stopping
# Restoring model weights from the end of the best epoch: 47.
# Loss for file mimic_perform_test_all_074_data.csv: 0.0548
# Processing: mimic_perform_test_all_075_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_075_data.csv: 0.0246
# Processing: mimic_perform_test_all_076_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_076_data.csv: 0.0240
# Processing: mimic_perform_test_all_077_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_077_data.csv: 0.1297
# Processing: mimic_perform_test_all_078_data.csv
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Loss for file mimic_perform_test_all_078_data.csv: 0.0497
# Processing: mimic_perform_test_all_079_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_079_data.csv: 0.0186
# Processing: mimic_perform_test_all_080_data.csv
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 20.
# Loss for file mimic_perform_test_all_080_data.csv: 0.1030
# Processing: mimic_perform_test_all_081_data.csv
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Loss for file mimic_perform_test_all_081_data.csv: 0.0178
# Processing: mimic_perform_test_all_082_data.csv
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Loss for file mimic_perform_test_all_082_data.csv: 0.0558
# Processing: mimic_perform_test_all_083_data.csv
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 15.
# Loss for file mimic_perform_test_all_083_data.csv: 0.0802
# Processing: mimic_perform_test_all_084_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_084_data.csv: 0.0271
# Processing: mimic_perform_test_all_085_data.csv
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 18.
# Loss for file mimic_perform_test_all_085_data.csv: 0.0294
# Processing: mimic_perform_test_all_086_data.csv
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Loss for file mimic_perform_test_all_086_data.csv: 0.0369
# Processing: mimic_perform_test_all_087_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_087_data.csv: 0.0318
# Processing: mimic_perform_test_all_088_data.csv
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 18.
# Loss for file mimic_perform_test_all_088_data.csv: 0.0346
# Processing: mimic_perform_test_all_089_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_089_data.csv: 0.0654
# Processing: mimic_perform_test_all_090_data.csv
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 22.
# Loss for file mimic_perform_test_all_090_data.csv: 0.0549
# Processing: mimic_perform_test_all_091_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_091_data.csv: 0.0551
# Processing: mimic_perform_test_all_092_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_test_all_092_data.csv: 0.0696
# Processing: mimic_perform_test_all_093_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_093_data.csv: 0.0482
# Processing: mimic_perform_test_all_094_data.csv
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 15.
# Loss for file mimic_perform_test_all_094_data.csv: 0.0321
# Processing: mimic_perform_test_all_095_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_095_data.csv: 0.0427
# Processing: mimic_perform_test_all_096_data.csv
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Loss for file mimic_perform_test_all_096_data.csv: 0.2776
# Processing: mimic_perform_test_all_097_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_097_data.csv: 0.0364
# Processing: mimic_perform_test_all_098_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_098_data.csv: 0.0444
# Processing: mimic_perform_test_all_099_data.csv
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.
# Loss for file mimic_perform_test_all_099_data.csv: 0.0243
# Processing: mimic_perform_test_all_100_data.csv
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Loss for file mimic_perform_test_all_100_data.csv: 0.0347
# Processing: mimic_perform_test_all_101_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_101_data.csv: 0.0927
# Processing: mimic_perform_test_all_102_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_102_data.csv: 0.0720
# Processing: mimic_perform_test_all_103_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_103_data.csv: 0.0693
# Processing: mimic_perform_test_all_104_data.csv
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 17.
# Loss for file mimic_perform_test_all_104_data.csv: 0.0721
# Processing: mimic_perform_test_all_105_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_105_data.csv: 0.0711
# Processing: mimic_perform_test_all_106_data.csv
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 19.
# Loss for file mimic_perform_test_all_106_data.csv: 0.0722
# Processing: mimic_perform_test_all_107_data.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file mimic_perform_test_all_107_data.csv: 0.0850
# Processing: mimic_perform_test_all_108_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_108_data.csv: 0.0749
# Processing: mimic_perform_test_all_109_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_109_data.csv: 0.0647
# Processing: mimic_perform_test_all_110_data.csv
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Loss for file mimic_perform_test_all_110_data.csv: 0.0947
# Processing: mimic_perform_test_all_111_data.csv
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Loss for file mimic_perform_test_all_111_data.csv: 0.0909
# Processing: mimic_perform_test_all_112_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_112_data.csv: 0.0975
# Processing: mimic_perform_test_all_113_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_113_data.csv: 0.0814
# Processing: mimic_perform_test_all_114_data.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file mimic_perform_test_all_114_data.csv: 0.0791
# Processing: mimic_perform_test_all_115_data.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file mimic_perform_test_all_115_data.csv: 0.0823
# Processing: mimic_perform_test_all_116_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_116_data.csv: 0.1028
# Processing: mimic_perform_test_all_117_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_117_data.csv: 0.1089
# Processing: mimic_perform_test_all_118_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_118_data.csv: 0.0906
# Processing: mimic_perform_test_all_119_data.csv
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 15.
# Loss for file mimic_perform_test_all_119_data.csv: 0.0849
# Processing: mimic_perform_test_all_120_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_120_data.csv: 0.0785
# Processing: mimic_perform_test_all_121_data.csv
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Loss for file mimic_perform_test_all_121_data.csv: 0.0869
# Processing: mimic_perform_test_all_122_data.csv
# Epoch 34: early stopping
# Restoring model weights from the end of the best epoch: 24.
# Loss for file mimic_perform_test_all_122_data.csv: 0.0882
# Processing: mimic_perform_test_all_123_data.csv
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Loss for file mimic_perform_test_all_123_data.csv: 0.0774
# Processing: mimic_perform_test_all_124_data.csv
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Loss for file mimic_perform_test_all_124_data.csv: 0.0822
# Processing: mimic_perform_test_all_125_data.csv
# Epoch 31: early stopping
# Restoring model weights from the end of the best epoch: 21.
# Loss for file mimic_perform_test_all_125_data.csv: 0.1157
# Processing: mimic_perform_test_all_126_data.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file mimic_perform_test_all_126_data.csv: 0.0985
# Processing: mimic_perform_test_all_127_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_test_all_127_data.csv: 0.0700
# Processing: mimic_perform_test_all_128_data.csv
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 18.
# Loss for file mimic_perform_test_all_128_data.csv: 0.0823
# Processing: mimic_perform_test_all_129_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_129_data.csv: 0.0682
# Processing: mimic_perform_test_all_130_data.csv
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 19.
# Loss for file mimic_perform_test_all_130_data.csv: 0.1123
# Processing: mimic_perform_test_all_131_data.csv
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 18.
# Loss for file mimic_perform_test_all_131_data.csv: 0.1178
# Processing: mimic_perform_test_all_132_data.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file mimic_perform_test_all_132_data.csv: 0.1191
# Processing: mimic_perform_test_all_133_data.csv
# Epoch 31: early stopping
# Restoring model weights from the end of the best epoch: 21.
# Loss for file mimic_perform_test_all_133_data.csv: 0.0980
# Processing: mimic_perform_test_all_134_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_134_data.csv: 0.0880
# Processing: mimic_perform_test_all_135_data.csv
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.
# Loss for file mimic_perform_test_all_135_data.csv: 0.1002
# Processing: mimic_perform_test_all_136_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_136_data.csv: 0.0845
# Processing: mimic_perform_test_all_137_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_137_data.csv: 0.0520
# Processing: mimic_perform_test_all_138_data.csv
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Loss for file mimic_perform_test_all_138_data.csv: 0.0580
# Processing: mimic_perform_test_all_139_data.csv
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Loss for file mimic_perform_test_all_139_data.csv: 0.0592
# Processing: mimic_perform_test_all_140_data.csv
# Epoch 45: early stopping
# Restoring model weights from the end of the best epoch: 35.
# Loss for file mimic_perform_test_all_140_data.csv: 0.0922
# Processing: mimic_perform_test_all_141_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_141_data.csv: 0.0728
# Processing: mimic_perform_test_all_142_data.csv
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Loss for file mimic_perform_test_all_142_data.csv: 0.0581
# Processing: mimic_perform_test_all_143_data.csv
# Epoch 34: early stopping
# Restoring model weights from the end of the best epoch: 24.
# Loss for file mimic_perform_test_all_143_data.csv: 0.0877
# Processing: mimic_perform_test_all_144_data.csv
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Loss for file mimic_perform_test_all_144_data.csv: 0.0602
# Processing: mimic_perform_test_all_145_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_145_data.csv: 0.0833
# Processing: mimic_perform_test_all_146_data.csv
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 17.
# Loss for file mimic_perform_test_all_146_data.csv: 0.0723
# Processing: mimic_perform_test_all_147_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_147_data.csv: 0.0546
# Processing: mimic_perform_test_all_148_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_148_data.csv: 0.0889
# Processing: mimic_perform_test_all_149_data.csv
# Epoch 39: early stopping
# Restoring model weights from the end of the best epoch: 29.
# Loss for file mimic_perform_test_all_149_data.csv: 0.0826
# Processing: mimic_perform_test_all_150_data.csv
# Epoch 35: early stopping
# Restoring model weights from the end of the best epoch: 25.
# Loss for file mimic_perform_test_all_150_data.csv: 0.1000
# Processing: mimic_perform_test_all_151_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_151_data.csv: 0.0880
# Processing: mimic_perform_test_all_152_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_152_data.csv: 0.0818
# Processing: mimic_perform_test_all_153_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_153_data.csv: 0.0768
# Processing: mimic_perform_test_all_154_data.csv
# Epoch 35: early stopping
# Restoring model weights from the end of the best epoch: 25.
# Loss for file mimic_perform_test_all_154_data.csv: 0.0663
# Processing: mimic_perform_test_all_155_data.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file mimic_perform_test_all_155_data.csv: 0.0751
# Processing: mimic_perform_test_all_156_data.csv
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 20.
# Loss for file mimic_perform_test_all_156_data.csv: 0.0610
# Processing: mimic_perform_test_all_157_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_157_data.csv: 0.0531
# Processing: mimic_perform_test_all_158_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_test_all_158_data.csv: 0.0722
# Processing: mimic_perform_test_all_159_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_test_all_159_data.csv: 0.0770
# Processing: mimic_perform_test_all_160_data.csv
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Loss for file mimic_perform_test_all_160_data.csv: 0.0735
# Processing: mimic_perform_test_all_161_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_161_data.csv: 0.0775
# Processing: mimic_perform_test_all_162_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_162_data.csv: 0.0721
# Processing: mimic_perform_test_all_163_data.csv
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Loss for file mimic_perform_test_all_163_data.csv: 0.0815
# Processing: mimic_perform_test_all_164_data.csv
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 15.
# Loss for file mimic_perform_test_all_164_data.csv: 0.0946
# Processing: mimic_perform_test_all_165_data.csv
# Epoch 35: early stopping
# Restoring model weights from the end of the best epoch: 25.
# Loss for file mimic_perform_test_all_165_data.csv: 0.0903
# Processing: mimic_perform_test_all_166_data.csv
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Loss for file mimic_perform_test_all_166_data.csv: 0.0886
# Processing: mimic_perform_test_all_167_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_167_data.csv: 0.0772
# Processing: mimic_perform_test_all_168_data.csv
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Loss for file mimic_perform_test_all_168_data.csv: 0.0893
# Processing: mimic_perform_test_all_169_data.csv
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Loss for file mimic_perform_test_all_169_data.csv: 0.0828
# Processing: mimic_perform_test_all_170_data.csv
# Epoch 49: early stopping
# Restoring model weights from the end of the best epoch: 39.
# Loss for file mimic_perform_test_all_170_data.csv: 0.0899
# Processing: mimic_perform_test_all_171_data.csv
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 20.
# Loss for file mimic_perform_test_all_171_data.csv: 0.0935
# Processing: mimic_perform_test_all_172_data.csv
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 15.
# Loss for file mimic_perform_test_all_172_data.csv: 0.0842
# Processing: mimic_perform_test_all_173_data.csv
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 17.
# Loss for file mimic_perform_test_all_173_data.csv: 0.0840
# Processing: mimic_perform_test_all_174_data.csv
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Loss for file mimic_perform_test_all_174_data.csv: 0.0808
# Processing: mimic_perform_test_all_175_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_test_all_175_data.csv: 0.0696
# Processing: mimic_perform_test_all_176_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_176_data.csv: 0.0822
# Processing: mimic_perform_test_all_177_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_177_data.csv: 0.0944
# Processing: mimic_perform_test_all_178_data.csv
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Loss for file mimic_perform_test_all_178_data.csv: 0.0830
# Processing: mimic_perform_test_all_179_data.csv
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.
# Loss for file mimic_perform_test_all_179_data.csv: 0.0919
# Processing: mimic_perform_test_all_180_data.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file mimic_perform_test_all_180_data.csv: 0.0905
# Processing: mimic_perform_test_all_181_data.csv
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.
# Loss for file mimic_perform_test_all_181_data.csv: 0.1447
# Processing: mimic_perform_test_all_182_data.csv
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Loss for file mimic_perform_test_all_182_data.csv: 0.0733
# Processing: mimic_perform_test_all_183_data.csv
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Loss for file mimic_perform_test_all_183_data.csv: 0.0986
# Processing: mimic_perform_test_all_184_data.csv
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 22.
# Loss for file mimic_perform_test_all_184_data.csv: 0.1017
# Processing: mimic_perform_test_all_185_data.csv
# Epoch 39: early stopping
# Restoring model weights from the end of the best epoch: 29.
# Loss for file mimic_perform_test_all_185_data.csv: 0.0818
# Processing: mimic_perform_test_all_186_data.csv
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Loss for file mimic_perform_test_all_186_data.csv: 0.0858
# Processing: mimic_perform_test_all_187_data.csv
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Loss for file mimic_perform_test_all_187_data.csv: 0.0515
# Processing: mimic_perform_test_all_188_data.csv
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Loss for file mimic_perform_test_all_188_data.csv: 0.0791
# Processing: mimic_perform_test_all_189_data.csv
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Loss for file mimic_perform_test_all_189_data.csv: 0.0907
# Processing: mimic_perform_test_all_190_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_190_data.csv: 0.0789
# Processing: mimic_perform_test_all_191_data.csv
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Loss for file mimic_perform_test_all_191_data.csv: 0.1042
# Processing: mimic_perform_test_all_192_data.csv
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 16.
# Loss for file mimic_perform_test_all_192_data.csv: 0.0809
# Processing: mimic_perform_test_all_193_data.csv
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Loss for file mimic_perform_test_all_193_data.csv: 0.0739
# Processing: mimic_perform_test_all_194_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_test_all_194_data.csv: 0.0895
# Processing: mimic_perform_test_all_195_data.csv
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Loss for file mimic_perform_test_all_195_data.csv: 0.0828
# Processing: mimic_perform_test_all_196_data.csv
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 19.
# Loss for file mimic_perform_test_all_196_data.csv: 0.0818
# Processing: mimic_perform_test_all_197_data.csv
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Loss for file mimic_perform_test_all_197_data.csv: 0.1125
# Processing: mimic_perform_test_all_198_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_198_data.csv: 0.0769
# Processing: mimic_perform_test_all_199_data.csv
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Loss for file mimic_perform_test_all_199_data.csv: 0.0895
# Processing: mimic_perform_test_all_200_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_200_data.csv: 0.0850
# Processing: p004829-2103-08-30-21-52.csv
# Restoring model weights from the end of the best epoch: 200.
# Loss for file p004829-2103-08-30-21-52.csv: 0.0299
# Processing: p013072-2194-01-22-16-13.csv
# Restoring model weights from the end of the best epoch: 197.
# Loss for file p013072-2194-01-22-16-13.csv: 0.0174
# Processing: p015852-2148-05-03-18-39.csv
# Restoring model weights from the end of the best epoch: 200.
# Loss for file p015852-2148-05-03-18-39.csv: 0.0219
# Processing: p016684-2188-01-29-00-06.csv
# Restoring model weights from the end of the best epoch: 200.
# Loss for file p016684-2188-01-29-00-06.csv: 0.0204
# Processing: p019608-2125-02-05-04-57.csv
# Restoring model weights from the end of the best epoch: 198.
# Loss for file p019608-2125-02-05-04-57.csv: 0.0169
# Processing: p022954-2136-02-29-17-52.csv
# Restoring model weights from the end of the best epoch: 198.
# Loss for file p022954-2136-02-29-17-52.csv: 0.0213
# Processing: p023824-2182-11-27-14-22.csv
# Restoring model weights from the end of the best epoch: 193.
# Loss for file p023824-2182-11-27-14-22.csv: 0.0159
# Processing: p025117-2202-03-15-20-28.csv
# Restoring model weights from the end of the best epoch: 199.
# Loss for file p025117-2202-03-15-20-28.csv: 0.0194
# Processing: p026377-2111-11-17-16-46.csv
# Restoring model weights from the end of the best epoch: 200.
# Loss for file p026377-2111-11-17-16-46.csv: 0.0190
# Processing: p026964-2143-09-30-11-59.csv
# Restoring model weights from the end of the best epoch: 200.
# Loss for file p026964-2143-09-30-11-59.csv: 0.0144
# Processing: p026964-2147-01-11-18-03.csv
# Restoring model weights from the end of the best epoch: 200.
# Loss for file p026964-2147-01-11-18-03.csv: 0.0186
# Processing: p029512-2188-02-27-18-10.csv
# Restoring model weights from the end of the best epoch: 200.
# Loss for file p029512-2188-02-27-18-10.csv: 0.0180
# Processing: p043613-2185-01-18-23-52.csv
# Restoring model weights from the end of the best epoch: 200.
# Loss for file p043613-2185-01-18-23-52.csv: 0.0849
# Processing: p050089-2157-08-23-16-37.csv
# Restoring model weights from the end of the best epoch: 198.
# Loss for file p050089-2157-08-23-16-37.csv: 0.0289
# Processing: p050384-2195-01-30-16-17.csv
# Restoring model weights from the end of the best epoch: 196.
# Loss for file p050384-2195-01-30-16-17.csv: 0.0124
# Processing: p055204-2132-06-30-09-34.csv
# Restoring model weights from the end of the best epoch: 199.
# Loss for file p055204-2132-06-30-09-34.csv: 0.0145
# Processing: p055204-2132-07-02-00-25.csv
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 18.
# Loss for file p055204-2132-07-02-00-25.csv: 0.4358
# Processing: p058932-2120-10-13-23-15.csv
# Restoring model weights from the end of the best epoch: 197.
# Loss for file p058932-2120-10-13-23-15.csv: 0.0123
# Processing: p062160-2153-10-03-05-39.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file p062160-2153-10-03-05-39.csv: 0.0206
# Processing: p062160-2153-10-03-14-49.csv
# Restoring model weights from the end of the best epoch: 200.
# Loss for file p062160-2153-10-03-14-49.csv: 0.0362
# Processing: p063039-2157-03-29-13-35.csv
# Epoch 129: early stopping
# Restoring model weights from the end of the best epoch: 119.
# Loss for file p063039-2157-03-29-13-35.csv: 0.0345
# Processing: p063628-2176-07-02-20-38.csv
# Restoring model weights from the end of the best epoch: 200.
# Loss for file p063628-2176-07-02-20-38.csv: 0.0191
# Processing: p063628-2176-07-04-11-30.csv
# Epoch 124: early stopping
# Restoring model weights from the end of the best epoch: 114.
# Loss for file p063628-2176-07-04-11-30.csv: 0.0421
# Processing: p068956-2107-04-21-16-05.csv
# Restoring model weights from the end of the best epoch: 197.
# Loss for file p068956-2107-04-21-16-05.csv: 0.0263
# Processing: p068956-2107-04-21-16-10.csv
# Restoring model weights from the end of the best epoch: 198.
# Loss for file p068956-2107-04-21-16-10.csv: 0.0224
# Processing: p069339-2133-12-09-21-14.csv
# Restoring model weights from the end of the best epoch: 197.
# Loss for file p069339-2133-12-09-21-14.csv: 0.0209
# Processing: p069339-2133-12-10-22-32.csv
# Restoring model weights from the end of the best epoch: 197.
# Loss for file p069339-2133-12-10-22-32.csv: 0.0155
# Processing: p075371-2119-08-22-00-53.csv
# Restoring model weights from the end of the best epoch: 194.
# Loss for file p075371-2119-08-22-00-53.csv: 0.0336
# Processing: p075371-2119-08-22-17-30.csv
# Restoring model weights from the end of the best epoch: 193.
# Loss for file p075371-2119-08-22-17-30.csv: 0.0273
# Processing: p075796-2198-05-18-21-46.csv
# Epoch 173: early stopping
# Restoring model weights from the end of the best epoch: 163.
# Loss for file p075796-2198-05-18-21-46.csv: 0.0207
# Processing: p075796-2198-05-19-16-50.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file p075796-2198-05-19-16-50.csv: 0.0426
# Processing: p075796-2198-07-25-23-40.csv
# Restoring model weights from the end of the best epoch: 199.
# Loss for file p075796-2198-07-25-23-40.csv: 0.0146
# Processing: p077729-2120-08-31-01-03.csv
# Epoch 148: early stopping
# Restoring model weights from the end of the best epoch: 138.
# Loss for file p077729-2120-08-31-01-03.csv: 0.0216
# Processing: p077729-2120-08-31-17-38.csv
# Restoring model weights from the end of the best epoch: 200.
# Loss for file p077729-2120-08-31-17-38.csv: 0.2103
# Processing: p079998-2101-10-21-21-31.csv
# Epoch 108: early stopping
# Restoring model weights from the end of the best epoch: 98.
# Loss for file p079998-2101-10-21-21-31.csv: 0.0418
# Processing: p081349-2120-02-11-20-56.csv
# Epoch 112: early stopping
# Restoring model weights from the end of the best epoch: 102.
# Loss for file p081349-2120-02-11-20-56.csv: 0.0193
# Processing: p085866-2178-03-20-17-11.csv
# Epoch 137: early stopping
# Restoring model weights from the end of the best epoch: 127.
# Loss for file p085866-2178-03-20-17-11.csv: 0.0240
# Processing: p087275-2108-09-27-12-32.csv
# Restoring model weights from the end of the best epoch: 199.
# Loss for file p087275-2108-09-27-12-32.csv: 0.0212
# Processing: p087275-2108-09-28-18-46.csv
# Epoch 162: early stopping
# Restoring model weights from the end of the best epoch: 152.
# Loss for file p087275-2108-09-28-18-46.csv: 0.0200
# Processing: p087675-2104-12-05-03-53.csv
# Epoch 112: early stopping
# Restoring model weights from the end of the best epoch: 102.
# Loss for file p087675-2104-12-05-03-53.csv: 0.0298
# Processing: p089565-2174-05-12-00-07.csv
# Restoring model weights from the end of the best epoch: 198.
# Loss for file p089565-2174-05-12-00-07.csv: 0.0111
# Processing: p089565-2174-05-13-13-03.csv
# Restoring model weights from the end of the best epoch: 197.
# Loss for file p089565-2174-05-13-13-03.csv: 0.0101
# Processing: p092289-2183-03-17-23-12.csv
# Epoch 170: early stopping
# Restoring model weights from the end of the best epoch: 160.
# Loss for file p092289-2183-03-17-23-12.csv: 0.0162
# Processing: p094847-2112-02-12-19-56.csv
# Restoring model weights from the end of the best epoch: 199.
# Loss for file p094847-2112-02-12-19-56.csv: 0.0184
# Processing: p097547-2125-10-21-23-43.csv
# Restoring model weights from the end of the best epoch: 195.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Loss for file p097547-2125-10-21-23-43.csv: 0.0290
# Global loss (average across all files): 0.0650
# Training complete, and the model has been saved.
