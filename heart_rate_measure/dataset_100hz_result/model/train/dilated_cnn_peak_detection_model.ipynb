# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, BatchNormalization, Activation, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras import Input
import sys
sys.path.append("../../common_tools/signal_processing")
from normalize_signal import normalize_ppg

# Updated CNN model
def create_dilated_cnn(input_shape):
    model = Sequential()
    model.add(Input(shape=input_shape))  # Specify input shape
    model.add(Conv1D(filters=4, kernel_size=3, dilation_rate=1, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('elu'))

    # Subsequent convolutional layers with increasing dilation rates
    dilation_rates = [2, 4, 8, 16, 32, 64]
    for rate in dilation_rates:
        model.add(Conv1D(filters=32, kernel_size=3, dilation_rate=rate, padding='same'))
        model.add(BatchNormalization())
        model.add(Activation('elu'))

    # Final convolutional layer with `segment_length` filters
    model.add(Conv1D(filters=1, kernel_size=1, activation='sigmoid'))
    return model

# Prepare PPG data and labels
def process_ppg_file(file_path, label_path, segment_length=256, normalization_range=(-1, 1)):
    """
    Read PPG signals and labels from files, normalize them, and divide into segments.
    """
    # Read PPG signal
    ppg_data = pd.read_csv(file_path, header=None).squeeze("columns").values
    normalized_ppg = normalize_ppg(ppg_data)

    peaks_indices = pd.read_csv(label_path, header=None).squeeze("columns").values
    labels, segments = [], []
    for i in range(0, len(normalized_ppg), segment_length):
        segment = normalized_ppg[i:i+segment_length]
        if len(segment) < segment_length:
            segment = np.pad(segment, (0, segment_length - len(segment)), 'constant', constant_values=0)
        segments.append(segment)
        label = np.zeros(segment_length)
        for peak in peaks_indices:
            if i <= peak < i + segment_length:
                peak_pos = peak - i
                label[max(0, peak_pos - 2):min(segment_length, peak_pos + 3)] = 1
        labels.append(label)
    return np.array(segments), np.array(labels)

# File paths
input_dir = 'E:/dilated_cnn_peak_detection_model_data/train/train_data/data'
label_dir = 'E:/dilated_cnn_peak_detection_model_data/train/train_data/label'
segment_length = 256  

# Create the model
input_shape = (segment_length, 1)
model = create_dilated_cnn(input_shape)

# Initialize optimizer with a low learning rate
initial_learning_rate = 1e-4
optimizer = Adam(learning_rate=initial_learning_rate)

# Compile the model
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Callbacks to reduce learning rate and stop early
reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, min_lr=1e-8, verbose=1)
early_stopping = EarlyStopping(monitor='loss', patience=10, verbose=1, restore_best_weights=True)

# Train the model with each file and calculate the global loss
global_loss = 0
file_count = 0

for file_name in os.listdir(input_dir):
    input_file = os.path.join(input_dir, file_name)
    label_file = os.path.join(label_dir, file_name.replace(".csv", "_labeled_peaks.csv"))
    if os.path.exists(label_file):
        print(f"Processing: {file_name}")
        ppg_segments, ppg_labels = process_ppg_file(input_file, label_file, segment_length)
        ppg_segments = np.expand_dims(ppg_segments, axis=-1)  # Reshape (samples, 256, 1)

        history = model.fit(
            ppg_segments,
            ppg_labels,
            epochs=200,  
            batch_size=32, 
            verbose=0,
            callbacks=[reduce_lr, early_stopping]
        )
        file_loss = history.history['loss'][-1]
        print(f"Loss for file {file_name}: {file_loss:.4f}")
        global_loss += file_loss
        file_count += 1

# Calculate the average global loss
global_loss /= file_count
print(f"Global loss (average across all files): {global_loss:.4f}")

# Save the trained model
model.save("../dilated_cnn_peak_detection_model.h5")
print("Training complete, and the model has been saved.")
# Out:
# Processing: mimic_perform_af_004_data.csv
# Restoring model weights from the end of the best epoch: 200.
# Loss for file mimic_perform_af_004_data.csv: 0.0353
# Processing: mimic_perform_af_005_data.csv
#
# Epoch 79: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 102: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 112: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 117: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#
# Epoch 123: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
#
# Epoch 128: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# Epoch 130: early stopping
# Restoring model weights from the end of the best epoch: 120.
# Loss for file mimic_perform_af_005_data.csv: 0.0153
# Processing: mimic_perform_af_006_data.csv
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
#
# Epoch 51: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-07.
#
# Epoch 58: ReduceLROnPlateau reducing learning rate to 1.9531249506599124e-07.
#
# Epoch 67: ReduceLROnPlateau reducing learning rate to 9.765624753299562e-08.
#
# Epoch 72: ReduceLROnPlateau reducing learning rate to 4.882812376649781e-08.
# Epoch 72: early stopping
# Restoring model weights from the end of the best epoch: 62.
# Loss for file mimic_perform_af_006_data.csv: 0.1887
# Processing: mimic_perform_af_007_data.csv
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 2.4414061883248905e-08.
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.2207030941624453e-08.
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 1e-08.
# Epoch 38: early stopping
# Restoring model weights from the end of the best epoch: 28.
# Loss for file mimic_perform_af_007_data.csv: 0.0483
# Processing: mimic_perform_af_008_data.csv
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Loss for file mimic_perform_af_008_data.csv: 0.0822
# Processing: mimic_perform_af_009_data.csv
# Epoch 31: early stopping
# Restoring model weights from the end of the best epoch: 21.
# Loss for file mimic_perform_af_009_data.csv: 0.0919
# Processing: mimic_perform_af_010_data.csv
# Epoch 44: early stopping
# Restoring model weights from the end of the best epoch: 34.
# Loss for file mimic_perform_af_010_data.csv: 0.0535
# Processing: mimic_perform_af_011_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_af_011_data.csv: 0.0771
# Processing: mimic_perform_af_012_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_af_012_data.csv: 0.0797
# Processing: mimic_perform_af_013_data.csv
# Epoch 99: early stopping
# Restoring model weights from the end of the best epoch: 89.
# Loss for file mimic_perform_af_013_data.csv: 0.0649
# Processing: mimic_perform_af_014_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_af_014_data.csv: 0.0634
# Processing: mimic_perform_af_015_data.csv
# Epoch 127: early stopping
# Restoring model weights from the end of the best epoch: 117.
# Loss for file mimic_perform_af_015_data.csv: 0.0326
# Processing: mimic_perform_af_016_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_af_016_data.csv: 0.0794
# Processing: mimic_perform_af_017_data.csv
# Epoch 79: early stopping
# Restoring model weights from the end of the best epoch: 69.
# Loss for file mimic_perform_af_017_data.csv: 0.0669
# Processing: mimic_perform_af_018_data.csv
# Epoch 42: early stopping
# Restoring model weights from the end of the best epoch: 32.
# Loss for file mimic_perform_af_018_data.csv: 0.0740
# Processing: mimic_perform_af_019_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_af_019_data.csv: 0.0580
# Processing: mimic_perform_non_af_004_data.csv
# Epoch 51: early stopping
# Restoring model weights from the end of the best epoch: 41.
# Loss for file mimic_perform_non_af_004_data.csv: 0.0994
# Processing: mimic_perform_non_af_005_data.csv
# Epoch 83: early stopping
# Restoring model weights from the end of the best epoch: 73.
# Loss for file mimic_perform_non_af_005_data.csv: 0.0414
# Processing: mimic_perform_non_af_006_data.csv
# Epoch 34: early stopping
# Restoring model weights from the end of the best epoch: 24.
# Loss for file mimic_perform_non_af_006_data.csv: 0.0297
# Processing: mimic_perform_non_af_007_data.csv
# Epoch 34: early stopping
# Restoring model weights from the end of the best epoch: 24.
# Loss for file mimic_perform_non_af_007_data.csv: 0.0470
# Processing: mimic_perform_non_af_008_data.csv
# Epoch 78: early stopping
# Restoring model weights from the end of the best epoch: 68.
# Loss for file mimic_perform_non_af_008_data.csv: 0.0456
# Processing: mimic_perform_non_af_009_data.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file mimic_perform_non_af_009_data.csv: 0.0195
# Processing: mimic_perform_non_af_010_data.csv
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Loss for file mimic_perform_non_af_010_data.csv: 0.0378
# Processing: mimic_perform_non_af_011_data.csv
# Restoring model weights from the end of the best epoch: 196.
# Loss for file mimic_perform_non_af_011_data.csv: 0.0334
# Processing: mimic_perform_non_af_012_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_non_af_012_data.csv: 0.1168
# Processing: mimic_perform_non_af_013_data.csv
# Epoch 33: early stopping
# Restoring model weights from the end of the best epoch: 23.
# Loss for file mimic_perform_non_af_013_data.csv: 0.0340
# Processing: mimic_perform_non_af_014_data.csv
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 22.
# Loss for file mimic_perform_non_af_014_data.csv: 0.3560
# Processing: mimic_perform_non_af_015_data.csv
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Loss for file mimic_perform_non_af_015_data.csv: 0.0223
# Processing: mimic_perform_non_af_016_data.csv
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.
# Loss for file mimic_perform_non_af_016_data.csv: 0.0292
# Processing: mimic_perform_test_all_004_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_004_data.csv: 0.0387
# Processing: mimic_perform_test_all_005_data.csv
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Loss for file mimic_perform_test_all_005_data.csv: 0.0380
# Processing: mimic_perform_test_all_006_data.csv
# Epoch 36: early stopping
# Restoring model weights from the end of the best epoch: 26.
# Loss for file mimic_perform_test_all_006_data.csv: 0.0249
# Processing: mimic_perform_test_all_007_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_007_data.csv: 0.1533
# Processing: mimic_perform_test_all_008_data.csv
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Loss for file mimic_perform_test_all_008_data.csv: 0.0326
# Processing: mimic_perform_test_all_009_data.csv
# Epoch 40: early stopping
# Restoring model weights from the end of the best epoch: 30.
# Loss for file mimic_perform_test_all_009_data.csv: 0.0411
# Processing: mimic_perform_test_all_010_data.csv
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.
# Loss for file mimic_perform_test_all_010_data.csv: 0.0418
# Processing: mimic_perform_test_all_011_data.csv
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Loss for file mimic_perform_test_all_011_data.csv: 0.1528
# Processing: mimic_perform_test_all_012_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_012_data.csv: 0.0670
# Processing: mimic_perform_test_all_013_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_013_data.csv: 0.0273
# Processing: mimic_perform_test_all_014_data.csv
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Loss for file mimic_perform_test_all_014_data.csv: 0.0881
# Processing: mimic_perform_test_all_015_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_015_data.csv: 0.1288
# Processing: mimic_perform_test_all_016_data.csv
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 17.
# Loss for file mimic_perform_test_all_016_data.csv: 0.0679
# Processing: mimic_perform_test_all_017_data.csv
# Epoch 42: early stopping
# Restoring model weights from the end of the best epoch: 32.
# Loss for file mimic_perform_test_all_017_data.csv: 0.0399
# Processing: mimic_perform_test_all_018_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_018_data.csv: 0.0251
# Processing: mimic_perform_test_all_019_data.csv
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Loss for file mimic_perform_test_all_019_data.csv: 0.0447
# Processing: mimic_perform_test_all_020_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_test_all_020_data.csv: 0.2069
# Processing: mimic_perform_test_all_021_data.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file mimic_perform_test_all_021_data.csv: 0.0771
# Processing: mimic_perform_test_all_022_data.csv
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Loss for file mimic_perform_test_all_022_data.csv: 0.0356
# Processing: mimic_perform_test_all_023_data.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file mimic_perform_test_all_023_data.csv: 0.0393
# Processing: mimic_perform_test_all_024_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_test_all_024_data.csv: 0.0293
# Processing: mimic_perform_test_all_025_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_025_data.csv: 0.0552
# Processing: mimic_perform_test_all_026_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_026_data.csv: 0.0257
# Processing: mimic_perform_test_all_027_data.csv
# Epoch 33: early stopping
# Restoring model weights from the end of the best epoch: 23.
# Loss for file mimic_perform_test_all_027_data.csv: 0.0498
# Processing: mimic_perform_test_all_028_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_028_data.csv: 0.0263
# Processing: mimic_perform_test_all_029_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_test_all_029_data.csv: 0.0260
# Processing: mimic_perform_test_all_030_data.csv
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Loss for file mimic_perform_test_all_030_data.csv: 0.2403
# Processing: mimic_perform_test_all_031_data.csv
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 17.
# Loss for file mimic_perform_test_all_031_data.csv: 0.0326
# Processing: mimic_perform_test_all_032_data.csv
# Epoch 43: early stopping
# Restoring model weights from the end of the best epoch: 33.
# Loss for file mimic_perform_test_all_032_data.csv: 0.0342
# Processing: mimic_perform_test_all_033_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_033_data.csv: 0.0650
# Processing: mimic_perform_test_all_034_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_034_data.csv: 0.0691
# Processing: mimic_perform_test_all_035_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_035_data.csv: 0.1223
# Processing: mimic_perform_test_all_036_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_036_data.csv: 0.0517
# Processing: mimic_perform_test_all_037_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_037_data.csv: 0.2468
# Processing: mimic_perform_test_all_038_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_038_data.csv: 0.0568
# Processing: mimic_perform_test_all_039_data.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file mimic_perform_test_all_039_data.csv: 0.0223
# Processing: mimic_perform_test_all_040_data.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file mimic_perform_test_all_040_data.csv: 0.0448
# Processing: mimic_perform_test_all_041_data.csv
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Loss for file mimic_perform_test_all_041_data.csv: 0.0327
# Processing: mimic_perform_test_all_042_data.csv
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Loss for file mimic_perform_test_all_042_data.csv: 0.0526
# Processing: mimic_perform_test_all_043_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_043_data.csv: 0.0424
# Processing: mimic_perform_test_all_044_data.csv
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Loss for file mimic_perform_test_all_044_data.csv: 0.0918
# Processing: mimic_perform_test_all_045_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_test_all_045_data.csv: 0.0277
# Processing: mimic_perform_test_all_046_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_046_data.csv: 0.0387
# Processing: mimic_perform_test_all_047_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_047_data.csv: 0.0593
# Processing: mimic_perform_test_all_048_data.csv
# Epoch 33: early stopping
# Restoring model weights from the end of the best epoch: 23.
# Loss for file mimic_perform_test_all_048_data.csv: 0.0318
# Processing: mimic_perform_test_all_049_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_049_data.csv: 0.0479
# Processing: mimic_perform_test_all_050_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_050_data.csv: 0.0410
# Processing: mimic_perform_test_all_051_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_051_data.csv: 0.0319
# Processing: mimic_perform_test_all_052_data.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file mimic_perform_test_all_052_data.csv: 0.1621
# Processing: mimic_perform_test_all_053_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_053_data.csv: 0.0242
# Processing: mimic_perform_test_all_054_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_test_all_054_data.csv: 0.0329
# Processing: mimic_perform_test_all_055_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_055_data.csv: 0.0252
# Processing: mimic_perform_test_all_056_data.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file mimic_perform_test_all_056_data.csv: 0.0296
# Processing: mimic_perform_test_all_057_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_057_data.csv: 0.0524
# Processing: mimic_perform_test_all_058_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_058_data.csv: 0.3074
# Processing: mimic_perform_test_all_059_data.csv
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 22.
# Loss for file mimic_perform_test_all_059_data.csv: 0.1142
# Processing: mimic_perform_test_all_060_data.csv
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Loss for file mimic_perform_test_all_060_data.csv: 0.0614
# Processing: mimic_perform_test_all_061_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_061_data.csv: 0.0640
# Processing: mimic_perform_test_all_062_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_test_all_062_data.csv: 0.0236
# Processing: mimic_perform_test_all_063_data.csv
# Epoch 54: early stopping
# Restoring model weights from the end of the best epoch: 44.
# Loss for file mimic_perform_test_all_063_data.csv: 0.0525
# Processing: mimic_perform_test_all_064_data.csv
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Loss for file mimic_perform_test_all_064_data.csv: 0.0512
# Processing: mimic_perform_test_all_065_data.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file mimic_perform_test_all_065_data.csv: 0.0534
# Processing: mimic_perform_test_all_066_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_066_data.csv: 0.0446
# Processing: mimic_perform_test_all_067_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_067_data.csv: 0.0780
# Processing: mimic_perform_test_all_068_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_068_data.csv: 0.0532
# Processing: mimic_perform_test_all_069_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_069_data.csv: 0.1473
# Processing: mimic_perform_test_all_070_data.csv
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Loss for file mimic_perform_test_all_070_data.csv: 0.0332
# Processing: mimic_perform_test_all_071_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_071_data.csv: 0.0352
# Processing: mimic_perform_test_all_072_data.csv
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 15.
# Loss for file mimic_perform_test_all_072_data.csv: 0.0375
# Processing: mimic_perform_test_all_073_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_073_data.csv: 0.0419
# Processing: mimic_perform_test_all_074_data.csv
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Loss for file mimic_perform_test_all_074_data.csv: 0.0430
# Processing: mimic_perform_test_all_075_data.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file mimic_perform_test_all_075_data.csv: 0.0227
# Processing: mimic_perform_test_all_076_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_076_data.csv: 0.0171
# Processing: mimic_perform_test_all_077_data.csv
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 22.
# Loss for file mimic_perform_test_all_077_data.csv: 0.1425
# Processing: mimic_perform_test_all_078_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_078_data.csv: 0.0554
# Processing: mimic_perform_test_all_079_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_079_data.csv: 0.0231
# Processing: mimic_perform_test_all_080_data.csv
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 16.
# Loss for file mimic_perform_test_all_080_data.csv: 0.0776
# Processing: mimic_perform_test_all_081_data.csv
# Epoch 34: early stopping
# Restoring model weights from the end of the best epoch: 24.
# Loss for file mimic_perform_test_all_081_data.csv: 0.0191
# Processing: mimic_perform_test_all_082_data.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file mimic_perform_test_all_082_data.csv: 0.0418
# Processing: mimic_perform_test_all_083_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_083_data.csv: 0.0495
# Processing: mimic_perform_test_all_084_data.csv
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Loss for file mimic_perform_test_all_084_data.csv: 0.0284
# Processing: mimic_perform_test_all_085_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_085_data.csv: 0.0335
# Processing: mimic_perform_test_all_086_data.csv
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 17.
# Loss for file mimic_perform_test_all_086_data.csv: 0.0231
# Processing: mimic_perform_test_all_087_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_087_data.csv: 0.0409
# Processing: mimic_perform_test_all_088_data.csv
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Loss for file mimic_perform_test_all_088_data.csv: 0.0352
# Processing: mimic_perform_test_all_089_data.csv
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Loss for file mimic_perform_test_all_089_data.csv: 0.0530
# Processing: mimic_perform_test_all_090_data.csv
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 15.
# Loss for file mimic_perform_test_all_090_data.csv: 0.0523
# Processing: mimic_perform_test_all_091_data.csv
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Loss for file mimic_perform_test_all_091_data.csv: 0.0511
# Processing: mimic_perform_test_all_092_data.csv
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Loss for file mimic_perform_test_all_092_data.csv: 0.0531
# Processing: mimic_perform_test_all_093_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_093_data.csv: 0.0531
# Processing: mimic_perform_test_all_094_data.csv
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.
# Loss for file mimic_perform_test_all_094_data.csv: 0.0268
# Processing: mimic_perform_test_all_095_data.csv
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 17.
# Loss for file mimic_perform_test_all_095_data.csv: 0.0626
# Processing: mimic_perform_test_all_096_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_096_data.csv: 0.2532
# Processing: mimic_perform_test_all_097_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_test_all_097_data.csv: 0.0417
# Processing: mimic_perform_test_all_098_data.csv
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Loss for file mimic_perform_test_all_098_data.csv: 0.0445
# Processing: mimic_perform_test_all_099_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_099_data.csv: 0.0295
# Processing: mimic_perform_test_all_100_data.csv
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Loss for file mimic_perform_test_all_100_data.csv: 0.0376
# Processing: mimic_perform_test_all_101_data.csv
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Loss for file mimic_perform_test_all_101_data.csv: 0.1048
# Processing: mimic_perform_test_all_102_data.csv
# Epoch 48: early stopping
# Restoring model weights from the end of the best epoch: 38.
# Loss for file mimic_perform_test_all_102_data.csv: 0.0918
# Processing: mimic_perform_test_all_103_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_103_data.csv: 0.0740
# Processing: mimic_perform_test_all_104_data.csv
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Loss for file mimic_perform_test_all_104_data.csv: 0.0882
# Processing: mimic_perform_test_all_105_data.csv
# Epoch 35: early stopping
# Restoring model weights from the end of the best epoch: 25.
# Loss for file mimic_perform_test_all_105_data.csv: 0.0974
# Processing: mimic_perform_test_all_106_data.csv
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Loss for file mimic_perform_test_all_106_data.csv: 0.0856
# Processing: mimic_perform_test_all_107_data.csv
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 15.
# Loss for file mimic_perform_test_all_107_data.csv: 0.1418
# Processing: mimic_perform_test_all_108_data.csv
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Loss for file mimic_perform_test_all_108_data.csv: 0.1026
# Processing: mimic_perform_test_all_109_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_test_all_109_data.csv: 0.0841
# Processing: mimic_perform_test_all_110_data.csv
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 20.
# Loss for file mimic_perform_test_all_110_data.csv: 0.1063
# Processing: mimic_perform_test_all_111_data.csv
# Epoch 38: early stopping
# Restoring model weights from the end of the best epoch: 28.
# Loss for file mimic_perform_test_all_111_data.csv: 0.0990
# Processing: mimic_perform_test_all_112_data.csv
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Loss for file mimic_perform_test_all_112_data.csv: 0.1117
# Processing: mimic_perform_test_all_113_data.csv
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Loss for file mimic_perform_test_all_113_data.csv: 0.1000
# Processing: mimic_perform_test_all_114_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_114_data.csv: 0.1103
# Processing: mimic_perform_test_all_115_data.csv
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Loss for file mimic_perform_test_all_115_data.csv: 0.0968
# Processing: mimic_perform_test_all_116_data.csv
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Loss for file mimic_perform_test_all_116_data.csv: 0.1178
# Processing: mimic_perform_test_all_117_data.csv
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 19.
# Loss for file mimic_perform_test_all_117_data.csv: 0.1699
# Processing: mimic_perform_test_all_118_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_118_data.csv: 0.1164
# Processing: mimic_perform_test_all_119_data.csv
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Loss for file mimic_perform_test_all_119_data.csv: 0.1209
# Processing: mimic_perform_test_all_120_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_test_all_120_data.csv: 0.0753
# Processing: mimic_perform_test_all_121_data.csv
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Loss for file mimic_perform_test_all_121_data.csv: 0.1342
# Processing: mimic_perform_test_all_122_data.csv
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 20.
# Loss for file mimic_perform_test_all_122_data.csv: 0.1328
# Processing: mimic_perform_test_all_123_data.csv
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.
# Loss for file mimic_perform_test_all_123_data.csv: 0.1025
# Processing: mimic_perform_test_all_124_data.csv
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 18.
# Loss for file mimic_perform_test_all_124_data.csv: 0.1001
# Processing: mimic_perform_test_all_125_data.csv
# Epoch 41: early stopping
# Restoring model weights from the end of the best epoch: 31.
# Loss for file mimic_perform_test_all_125_data.csv: 0.2035
# Processing: mimic_perform_test_all_126_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_126_data.csv: 0.1548
# Processing: mimic_perform_test_all_127_data.csv
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 18.
# Loss for file mimic_perform_test_all_127_data.csv: 0.0943
# Processing: mimic_perform_test_all_128_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_128_data.csv: 0.0891
# Processing: mimic_perform_test_all_129_data.csv
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Loss for file mimic_perform_test_all_129_data.csv: 0.0937
# Processing: mimic_perform_test_all_130_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_130_data.csv: 0.1227
# Processing: mimic_perform_test_all_131_data.csv
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Loss for file mimic_perform_test_all_131_data.csv: 0.1513
# Processing: mimic_perform_test_all_132_data.csv
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Loss for file mimic_perform_test_all_132_data.csv: 0.1282
# Processing: mimic_perform_test_all_133_data.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file mimic_perform_test_all_133_data.csv: 0.1427
# Processing: mimic_perform_test_all_134_data.csv
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 19.
# Loss for file mimic_perform_test_all_134_data.csv: 0.0902
# Processing: mimic_perform_test_all_135_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_135_data.csv: 0.1071
# Processing: mimic_perform_test_all_136_data.csv
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Loss for file mimic_perform_test_all_136_data.csv: 0.1276
# Processing: mimic_perform_test_all_137_data.csv
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Loss for file mimic_perform_test_all_137_data.csv: 0.0680
# Processing: mimic_perform_test_all_138_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_138_data.csv: 0.0991
# Processing: mimic_perform_test_all_139_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_139_data.csv: 0.0643
# Processing: mimic_perform_test_all_140_data.csv
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 19.
# Loss for file mimic_perform_test_all_140_data.csv: 0.1265
# Processing: mimic_perform_test_all_141_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_141_data.csv: 0.1011
# Processing: mimic_perform_test_all_142_data.csv
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Loss for file mimic_perform_test_all_142_data.csv: 0.0743
# Processing: mimic_perform_test_all_143_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_143_data.csv: 0.1338
# Processing: mimic_perform_test_all_144_data.csv
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 19.
# Loss for file mimic_perform_test_all_144_data.csv: 0.0637
# Processing: mimic_perform_test_all_145_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_test_all_145_data.csv: 0.1304
# Processing: mimic_perform_test_all_146_data.csv
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Loss for file mimic_perform_test_all_146_data.csv: 0.0740
# Processing: mimic_perform_test_all_147_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_147_data.csv: 0.0775
# Processing: mimic_perform_test_all_148_data.csv
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Loss for file mimic_perform_test_all_148_data.csv: 0.1166
# Processing: mimic_perform_test_all_149_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_149_data.csv: 0.1026
# Processing: mimic_perform_test_all_150_data.csv
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Loss for file mimic_perform_test_all_150_data.csv: 0.1598
# Processing: mimic_perform_test_all_151_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_151_data.csv: 0.0959
# Processing: mimic_perform_test_all_152_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_152_data.csv: 0.1107
# Processing: mimic_perform_test_all_153_data.csv
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Loss for file mimic_perform_test_all_153_data.csv: 0.1111
# Processing: mimic_perform_test_all_154_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_154_data.csv: 0.0995
# Processing: mimic_perform_test_all_155_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_155_data.csv: 0.1163
# Processing: mimic_perform_test_all_156_data.csv
# Epoch 39: early stopping
# Restoring model weights from the end of the best epoch: 29.
# Loss for file mimic_perform_test_all_156_data.csv: 0.0666
# Processing: mimic_perform_test_all_157_data.csv
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Loss for file mimic_perform_test_all_157_data.csv: 0.1964
# Processing: mimic_perform_test_all_158_data.csv
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 19.
# Loss for file mimic_perform_test_all_158_data.csv: 0.0894
# Processing: mimic_perform_test_all_159_data.csv
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Loss for file mimic_perform_test_all_159_data.csv: 0.0849
# Processing: mimic_perform_test_all_160_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_160_data.csv: 0.1127
# Processing: mimic_perform_test_all_161_data.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file mimic_perform_test_all_161_data.csv: 0.0783
# Processing: mimic_perform_test_all_162_data.csv
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Loss for file mimic_perform_test_all_162_data.csv: 0.1191
# Processing: mimic_perform_test_all_163_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_163_data.csv: 0.1013
# Processing: mimic_perform_test_all_164_data.csv
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Loss for file mimic_perform_test_all_164_data.csv: 0.1123
# Processing: mimic_perform_test_all_165_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_165_data.csv: 0.1061
# Processing: mimic_perform_test_all_166_data.csv
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.
# Loss for file mimic_perform_test_all_166_data.csv: 0.0967
# Processing: mimic_perform_test_all_167_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_167_data.csv: 0.0981
# Processing: mimic_perform_test_all_168_data.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file mimic_perform_test_all_168_data.csv: 0.1160
# Processing: mimic_perform_test_all_169_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_test_all_169_data.csv: 0.1366
# Processing: mimic_perform_test_all_170_data.csv
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Loss for file mimic_perform_test_all_170_data.csv: 0.1004
# Processing: mimic_perform_test_all_171_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_test_all_171_data.csv: 0.1028
# Processing: mimic_perform_test_all_172_data.csv
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 19.
# Loss for file mimic_perform_test_all_172_data.csv: 0.1146
# Processing: mimic_perform_test_all_173_data.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file mimic_perform_test_all_173_data.csv: 0.1147
# Processing: mimic_perform_test_all_174_data.csv
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Loss for file mimic_perform_test_all_174_data.csv: 0.0889
# Processing: mimic_perform_test_all_175_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_test_all_175_data.csv: 0.0926
# Processing: mimic_perform_test_all_176_data.csv
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 20.
# Loss for file mimic_perform_test_all_176_data.csv: 0.1314
# Processing: mimic_perform_test_all_177_data.csv
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Loss for file mimic_perform_test_all_177_data.csv: 0.1299
# Processing: mimic_perform_test_all_178_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_178_data.csv: 0.0955
# Processing: mimic_perform_test_all_179_data.csv
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Loss for file mimic_perform_test_all_179_data.csv: 0.0958
# Processing: mimic_perform_test_all_180_data.csv
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Loss for file mimic_perform_test_all_180_data.csv: 0.0981
# Processing: mimic_perform_test_all_181_data.csv
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Loss for file mimic_perform_test_all_181_data.csv: 0.1562
# Processing: mimic_perform_test_all_182_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_test_all_182_data.csv: 0.1014
# Processing: mimic_perform_test_all_183_data.csv
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Loss for file mimic_perform_test_all_183_data.csv: 0.1157
# Processing: mimic_perform_test_all_184_data.csv
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Loss for file mimic_perform_test_all_184_data.csv: 0.1167
# Processing: mimic_perform_test_all_185_data.csv
# Epoch 31: early stopping
# Restoring model weights from the end of the best epoch: 21.
# Loss for file mimic_perform_test_all_185_data.csv: 0.1047
# Processing: mimic_perform_test_all_186_data.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file mimic_perform_test_all_186_data.csv: 0.1128
# Processing: mimic_perform_test_all_187_data.csv
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Loss for file mimic_perform_test_all_187_data.csv: 0.0623
# Processing: mimic_perform_test_all_188_data.csv
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Loss for file mimic_perform_test_all_188_data.csv: 0.1055
# Processing: mimic_perform_test_all_189_data.csv
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Loss for file mimic_perform_test_all_189_data.csv: 0.0988
# Processing: mimic_perform_test_all_190_data.csv
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Loss for file mimic_perform_test_all_190_data.csv: 0.0827
# Processing: mimic_perform_test_all_191_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_191_data.csv: 0.1289
# Processing: mimic_perform_test_all_192_data.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file mimic_perform_test_all_192_data.csv: 0.1107
# Processing: mimic_perform_test_all_193_data.csv
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Loss for file mimic_perform_test_all_193_data.csv: 0.0772
# Processing: mimic_perform_test_all_194_data.csv
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 15.
# Loss for file mimic_perform_test_all_194_data.csv: 0.1159
# Processing: mimic_perform_test_all_195_data.csv
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 22.
# Loss for file mimic_perform_test_all_195_data.csv: 0.1015
# Processing: mimic_perform_test_all_196_data.csv
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Loss for file mimic_perform_test_all_196_data.csv: 0.1047
# Processing: mimic_perform_test_all_197_data.csv
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Loss for file mimic_perform_test_all_197_data.csv: 0.1275
# Processing: mimic_perform_test_all_198_data.csv
# Epoch 33: early stopping
# Restoring model weights from the end of the best epoch: 23.
# Loss for file mimic_perform_test_all_198_data.csv: 0.0899
# Processing: mimic_perform_test_all_199_data.csv
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Loss for file mimic_perform_test_all_199_data.csv: 0.1169
# Processing: mimic_perform_test_all_200_data.csv
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Loss for file mimic_perform_test_all_200_data.csv: 0.1226
# Processing: p015852-2148-05-03-18-39.csv
# Restoring model weights from the end of the best epoch: 198.
# Loss for file p015852-2148-05-03-18-39.csv: 0.0222
# Processing: p016684-2188-01-29-00-06.csv
# Restoring model weights from the end of the best epoch: 199.
# Loss for file p016684-2188-01-29-00-06.csv: 0.0204
# Processing: p019608-2125-02-05-04-57.csv
# Restoring model weights from the end of the best epoch: 199.
# Loss for file p019608-2125-02-05-04-57.csv: 0.0165
# Processing: p022954-2136-02-29-17-52.csv
# Restoring model weights from the end of the best epoch: 199.
# Loss for file p022954-2136-02-29-17-52.csv: 0.0212
# Processing: p023824-2182-11-27-14-22.csv
# Epoch 179: early stopping
# Restoring model weights from the end of the best epoch: 169.
# Loss for file p023824-2182-11-27-14-22.csv: 0.0156
# Processing: p025117-2202-03-15-20-28.csv
# Epoch 153: early stopping
# Restoring model weights from the end of the best epoch: 143.
# Loss for file p025117-2202-03-15-20-28.csv: 0.0194
# Processing: p025117-2202-03-17-09-14.csv
# Epoch 40: early stopping
# Restoring model weights from the end of the best epoch: 30.
# Loss for file p025117-2202-03-17-09-14.csv: 0.0163
# Processing: p026377-2111-11-17-16-46.csv
# Restoring model weights from the end of the best epoch: 199.
# Loss for file p026377-2111-11-17-16-46.csv: 0.0196
# Processing: p026964-2143-09-30-11-59.csv
# Restoring model weights from the end of the best epoch: 200.
# Loss for file p026964-2143-09-30-11-59.csv: 0.0143
# Processing: p026964-2147-01-11-18-03.csv
# Restoring model weights from the end of the best epoch: 195.
# Loss for file p026964-2147-01-11-18-03.csv: 0.0190
# Processing: p029512-2188-02-27-18-10.csv
# Restoring model weights from the end of the best epoch: 197.
# Loss for file p029512-2188-02-27-18-10.csv: 0.0186
# Processing: p043613-2185-01-18-23-52.csv
# Restoring model weights from the end of the best epoch: 200.
# Loss for file p043613-2185-01-18-23-52.csv: 0.1197
# Processing: p050089-2157-08-23-16-37.csv
# Restoring model weights from the end of the best epoch: 199.
# Loss for file p050089-2157-08-23-16-37.csv: 0.0313
# Processing: p050384-2195-01-30-02-21.csv
# Restoring model weights from the end of the best epoch: 200.
# Loss for file p050384-2195-01-30-02-21.csv: 0.0118
# Processing: p050384-2195-01-30-16-17.csv
# Restoring model weights from the end of the best epoch: 200.
# Loss for file p050384-2195-01-30-16-17.csv: 0.0121
# Processing: p055204-2132-06-30-09-34.csv
# Restoring model weights from the end of the best epoch: 198.
# Loss for file p055204-2132-06-30-09-34.csv: 0.0142
# Processing: p055204-2132-07-02-00-25.csv
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 15.
# Loss for file p055204-2132-07-02-00-25.csv: 0.6064
# Processing: p058932-2120-10-13-23-15.csv
# Restoring model weights from the end of the best epoch: 196.
# Loss for file p058932-2120-10-13-23-15.csv: 0.0119
# Processing: p062160-2153-10-03-05-39.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file p062160-2153-10-03-05-39.csv: 0.0263
# Processing: p062160-2153-10-03-14-49.csv
# Restoring model weights from the end of the best epoch: 197.
# Loss for file p062160-2153-10-03-14-49.csv: 0.0363
# Processing: p063039-2157-03-29-13-35.csv
# Epoch 76: early stopping
# Restoring model weights from the end of the best epoch: 66.
# Loss for file p063039-2157-03-29-13-35.csv: 0.0357
# Processing: p063628-2176-07-02-20-38.csv
# Restoring model weights from the end of the best epoch: 200.
# Loss for file p063628-2176-07-02-20-38.csv: 0.0191
# Processing: p063628-2176-07-04-11-30.csv
# Epoch 181: early stopping
# Restoring model weights from the end of the best epoch: 171.
# Loss for file p063628-2176-07-04-11-30.csv: 0.0430
# Processing: p063628-2176-07-05-17-12.csv
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Loss for file p063628-2176-07-05-17-12.csv: 0.0399
# Processing: p068956-2107-04-21-16-05.csv
# Restoring model weights from the end of the best epoch: 200.
# Loss for file p068956-2107-04-21-16-05.csv: 0.0290
# Processing: p068956-2107-04-21-16-10.csv
# Restoring model weights from the end of the best epoch: 196.
# Loss for file p068956-2107-04-21-16-10.csv: 0.0225
# Processing: p069339-2133-12-09-21-14.csv
# Restoring model weights from the end of the best epoch: 200.
# Loss for file p069339-2133-12-09-21-14.csv: 0.0215
# Processing: p069339-2133-12-10-22-32.csv
# Restoring model weights from the end of the best epoch: 199.
# Loss for file p069339-2133-12-10-22-32.csv: 0.0157
# Processing: p075371-2119-08-22-00-53.csv
# Restoring model weights from the end of the best epoch: 200.
# Loss for file p075371-2119-08-22-00-53.csv: 0.0379
# Processing: p075371-2119-08-22-17-30.csv
# Restoring model weights from the end of the best epoch: 199.
# Loss for file p075371-2119-08-22-17-30.csv: 0.0284
# Processing: p075796-2198-05-18-21-46.csv
# Restoring model weights from the end of the best epoch: 197.
# Loss for file p075796-2198-05-18-21-46.csv: 0.0212
# Processing: p075796-2198-05-19-16-50.csv
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Loss for file p075796-2198-05-19-16-50.csv: 0.0515
# Processing: p075796-2198-07-25-22-55.csv
# Epoch 103: early stopping
# Restoring model weights from the end of the best epoch: 93.
# Loss for file p075796-2198-07-25-22-55.csv: 0.0229
# Processing: p075796-2198-07-25-23-40.csv
# Restoring model weights from the end of the best epoch: 197.
# Loss for file p075796-2198-07-25-23-40.csv: 0.0146
# Processing: p077729-2120-08-31-01-03.csv
# Restoring model weights from the end of the best epoch: 200.
# Loss for file p077729-2120-08-31-01-03.csv: 0.0214
# Processing: p077729-2120-08-31-17-38.csv
# Restoring model weights from the end of the best epoch: 200.
# Loss for file p077729-2120-08-31-17-38.csv: 0.3006
# Processing: p079998-2101-10-21-21-31.csv
# Epoch 74: early stopping
# Restoring model weights from the end of the best epoch: 64.
# Loss for file p079998-2101-10-21-21-31.csv: 0.0458
# Processing: p081349-2120-02-11-06-35.csv
# Epoch 183: early stopping
# Restoring model weights from the end of the best epoch: 173.
# Loss for file p081349-2120-02-11-06-35.csv: 0.0267
# Processing: p081349-2120-02-11-20-56.csv
# Epoch 40: early stopping
# Restoring model weights from the end of the best epoch: 30.
# Loss for file p081349-2120-02-11-20-56.csv: 0.0189
# Processing: p085866-2178-03-20-17-11.csv
# Epoch 118: early stopping
# Restoring model weights from the end of the best epoch: 108.
# Loss for file p085866-2178-03-20-17-11.csv: 0.0241
# Processing: p087275-2108-08-29-12-53.csv
# Epoch 125: early stopping
# Restoring model weights from the end of the best epoch: 115.
# Loss for file p087275-2108-08-29-12-53.csv: 0.0249
# Processing: p087275-2108-09-27-12-32.csv
# Restoring model weights from the end of the best epoch: 198.
# Loss for file p087275-2108-09-27-12-32.csv: 0.0210
# Processing: p087275-2108-09-28-18-46.csv
# Epoch 129: early stopping
# Restoring model weights from the end of the best epoch: 119.
# Loss for file p087275-2108-09-28-18-46.csv: 0.0199
# Processing: p087675-2104-12-04-20-08.csv
# Epoch 134: early stopping
# Restoring model weights from the end of the best epoch: 124.
# Loss for file p087675-2104-12-04-20-08.csv: 0.0130
# Processing: p087675-2104-12-05-03-53.csv
# Restoring model weights from the end of the best epoch: 193.
# Loss for file p087675-2104-12-05-03-53.csv: 0.0353
# Processing: p089565-2174-05-12-00-07.csv
# Restoring model weights from the end of the best epoch: 199.
# Loss for file p089565-2174-05-12-00-07.csv: 0.0111
# Processing: p089565-2174-05-13-13-03.csv
# Restoring model weights from the end of the best epoch: 200.
# Loss for file p089565-2174-05-13-13-03.csv: 0.0097
# Processing: p092289-2183-03-17-23-12.csv
# Epoch 134: early stopping
# Restoring model weights from the end of the best epoch: 124.
# Loss for file p092289-2183-03-17-23-12.csv: 0.0167
# Processing: p092846-2129-12-21-13-12.csv
# Restoring model weights from the end of the best epoch: 200.
# Loss for file p092846-2129-12-21-13-12.csv: 0.0172
# Processing: p094847-2112-02-12-19-56.csv
# Restoring model weights from the end of the best epoch: 200.
# Loss for file p094847-2112-02-12-19-56.csv: 0.0179
# Processing: p094847-2112-02-14-06-52.csv
# Restoring model weights from the end of the best epoch: 200.
# Loss for file p094847-2112-02-14-06-52.csv: 0.0212
# Processing: p097547-2125-10-21-23-43.csv
# Restoring model weights from the end of the best epoch: 200.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Loss for file p097547-2125-10-21-23-43.csv: 0.0278
# Global loss (average across all files): 0.0755
# Training complete, and the model has been saved.
