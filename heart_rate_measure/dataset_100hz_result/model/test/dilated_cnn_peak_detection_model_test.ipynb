# %%
import os
import pandas as pd
import numpy as np
import glob
from tensorflow.keras.models import load_model
import sys
sys.path.append("../../common_tools/peaks_confusion_matrix")
from confusion_matrix import compute_confusion_matrix
from plot_false_peaks import plot_fp_fn
sys.path.append("../../common_tools/signal_processing")
from normalize_signal import normalize_ppg

# %%
# Function to filter out close peaks
def filter_close_peaks(peaks, signal, tolerance):
    """
    Retains only the highest peak in each group of close peaks.

    Args:
        peaks (list): List of detected peak indices.
        signal (array): PPG signal data.
        tolerance (int): Minimum distance between peaks to consider them separate.

    Returns:
        list: List of filtered peaks with only the highest peak in each group.
    """
    if not peaks:
        return []

    filtered_peaks = []
    current_group = [peaks[0]]  # Initialize the first group
    
    for peak in peaks[1:]:
        if peak - current_group[-1] <= tolerance:
            current_group.append(peak)  # Add to the current group if within tolerance
        else:
            # Select the peak with the highest value in the group
            valid_peaks = [p for p in current_group if p < len(signal)]  # Ensure valid indices
            if valid_peaks:  # Avoid empty list
                best_peak = max(valid_peaks, key=lambda x: signal[x])
                filtered_peaks.append(best_peak)
            current_group = [peak]  # Start a new group
    
    # Process the last group
    valid_peaks = [p for p in current_group if p < len(signal)]
    if valid_peaks:
        best_peak = max(valid_peaks, key=lambda x: signal[x])
        filtered_peaks.append(best_peak)

    return filtered_peaks

# Function to detect peaks using a trained model
def detect_peaks_with_model(ppg_data, model, segment_length=256, threshold=0.7, fs=100):
    """
    Detect PPG peaks using a trained model and filter out close peaks.
    
    Args:
        ppg_data (array): Input PPG signal data.
        model (keras.Model): Pre-trained model.
        segment_length (int): Length of each processing segment.
        threshold (float): Probability threshold for peak detection.
        fs (int): Sampling frequency, default is 100 Hz.
    
    Returns:
        list: List of filtered peak indices.
    """
    detected_peaks = []
    tolerance = int(0.3 * fs)
    
    for i in range(0, len(ppg_data), segment_length):
        segment = ppg_data[i:i+segment_length]
        if len(segment) < segment_length:
            segment = np.pad(segment, (0, segment_length - len(segment)), 'constant', constant_values=0)
        segment = np.expand_dims(np.expand_dims(segment, axis=0), axis=-1)  
        
        predictions = model.predict(segment, verbose=0)
        predictions = predictions.flatten()  
        
        for idx, value in enumerate(predictions):
            if value > threshold:  
                detected_peaks.append(i + idx)
    
    # Filter out close peaks
    detected_peaks = filter_close_peaks(detected_peaks, ppg_data, tolerance)
    
    return detected_peaks

# %%
# Paths
test_data_dir = 'E:/dilated_cnn_peak_detection_model_data/test/test_data/data'
label_dir = 'E:/dilated_cnn_peak_detection_model_data/test/test_data/label'
output_dir = 'E:/dilated_cnn_peak_detection_model_data/test/model_detected_peaks/'
plot_output_dir = 'E:/dilated_cnn_peak_detection_model_data/test/model_plot_results/'

# Create directory to save results
os.makedirs(output_dir, exist_ok=True)
os.makedirs(plot_output_dir, exist_ok=True)

for file in glob.glob(os.path.join(output_dir, "*.csv")):
    os.remove(file)

for file in glob.glob(os.path.join(plot_output_dir, "*.png")):
    os.remove(file)

# %%
# Load the model
model = load_model("../dilated_cnn_peak_detection_model.h5")

# Test and save results
total_tp, total_fp, total_fn = 0, 0, 0
num_files = 0

for file_name in os.listdir(test_data_dir):
    input_file = os.path.join(test_data_dir, file_name)
    label_file = os.path.join(label_dir, file_name.replace(".csv", "_labeled_peaks.csv"))
    if os.path.exists(label_file):
        print(f"Processing: {file_name}")
        
        # Read and normalize data
        ppg_data = pd.read_csv(input_file, header=None).squeeze("columns").values
        ppg_data = normalize_ppg(ppg_data)
        labeled_peaks = pd.read_csv(label_file, header=None).squeeze("columns").values

        # Detect peaks
        detected_peaks = detect_peaks_with_model(ppg_data, model)

        # Save detected peaks
        detected_file = os.path.join(output_dir, file_name.replace(".csv", "_detected_peaks.csv"))
        pd.DataFrame(detected_peaks).to_csv(detected_file, header=False, index=False)

        # Compute confusion matrix
        results = compute_confusion_matrix(detected_peaks, labeled_peaks)
        print(f"File: {file_name}")
        print(f"True Positives (TP): {results['tp']}")
        print(f"False Positives (FP): {results['fp']}")
        print(f"False Negatives (FN): {results['fn']}")
        print(f"Accuracy: {results['accuracy']:.2f}")
        print(f"Precision: {results['precision']:.2f}")
        print(f"Recall: {results['recall']:.2f}")
        print(f"Detection Error Rate: {results['der']:.2f}")
        print("False Positives (FP) at indices:", results['fp_list'])
        print("False Negatives (FN) at indices:", results['fn_list'])
        print("")

        # Accumulate statistics
        total_tp += results['tp']
        total_fp += results['fp']
        total_fn += results['fn']
        num_files += 1

        # Plot False Positives and False Negatives
        plot_fp_fn(ppg_data, results['fp_list'], results['fn_list'], detected_peaks, file_name, plot_output_dir)

# Compute overall metrics
if num_files > 0:
    overall_precision = total_tp / (total_tp + total_fp) if (total_tp + total_fp) > 0 else 0
    overall_recall = total_tp / (total_tp + total_fn) if (total_tp + total_fn) > 0 else 0
    overall_accuracy = total_tp / (total_tp + total_fp + total_fn) if (total_tp + total_fp + total_fn) > 0 else 0
    overall_der = (total_fp + total_fn) / (total_tp + total_fp + total_fn) if (total_tp + total_fp + total_fn) > 0 else 0

    print("\n===== Overall Performance =====")
    print(f"Total Files Processed: {num_files}")
    print(f"Overall Accuracy: {overall_accuracy:.2f}")
    print(f"Overall Precision: {overall_precision:.2f}")
    print(f"Overall Recall: {overall_recall:.2f}")
    print(f"Overall Detection Error Rate (DER): {overall_der:.2f}")
else:
    print("No valid files processed.")
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Processing: 0009_8min_signal.csv
# File: 0009_8min_signal.csv
# True Positives (TP): 810
# False Positives (FP): 0
# False Negatives (FN): 6
# Accuracy: 0.99
# Precision: 1.00
# Recall: 0.99
# Detection Error Rate: 0.01
# False Positives (FP) at indices: []
# False Negatives (FN) at indices: [9726, 15102, 18810, 19150, 20948, 33022]
#
# Processing: 0015_8min_signal.csv
# File: 0015_8min_signal.csv
# True Positives (TP): 959
# False Positives (FP): 1
# False Negatives (FN): 1
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# Detection Error Rate: 0.00
# False Positives (FP) at indices: [37725]
# False Negatives (FN) at indices: [37717]
#
# Processing: 0016_8min_signal.csv
# File: 0016_8min_signal.csv
# True Positives (TP): 1000
# False Positives (FP): 3
# False Negatives (FN): 2
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# Detection Error Rate: 0.01
# False Positives (FP) at indices: [1723, 1774, 47998]
# False Negatives (FN) at indices: [1694, 1762]
#
# Processing: 0018_8min_signal.csv
# File: 0018_8min_signal.csv
# True Positives (TP): 1126
# False Positives (FP): 1
# False Negatives (FN): 0
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# Detection Error Rate: 0.00
# False Positives (FP) at indices: [4]
# False Negatives (FN) at indices: []
#
# Processing: 0023_8min_signal.csv
# File: 0023_8min_signal.csv
# True Positives (TP): 817
# False Positives (FP): 2
# False Negatives (FN): 0
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# Detection Error Rate: 0.00
# False Positives (FP) at indices: [7, 47998]
# False Negatives (FN) at indices: []
#
# Processing: 0028_8min_signal.csv
# File: 0028_8min_signal.csv
# True Positives (TP): 588
# False Positives (FP): 0
# False Negatives (FN): 0
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# Detection Error Rate: 0.00
# False Positives (FP) at indices: []
# False Negatives (FN) at indices: []
#
# Processing: 0029_8min_signal.csv
# File: 0029_8min_signal.csv
# True Positives (TP): 545
# False Positives (FP): 2
# False Negatives (FN): 0
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# Detection Error Rate: 0.00
# False Positives (FP) at indices: [7, 47998]
# False Negatives (FN) at indices: []
#
# Processing: 0030_8min_signal.csv
# File: 0030_8min_signal.csv
# True Positives (TP): 926
# False Positives (FP): 1
# False Negatives (FN): 1
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# Detection Error Rate: 0.00
# False Positives (FP) at indices: [4]
# False Negatives (FN) at indices: [47102]
#
# Processing: 0031_8min_signal.csv
# File: 0031_8min_signal.csv
# True Positives (TP): 539
# False Positives (FP): 1
# False Negatives (FN): 7
# Accuracy: 0.99
# Precision: 1.00
# Recall: 0.99
# Detection Error Rate: 0.01
# False Positives (FP) at indices: [6]
# False Negatives (FN) at indices: [42028, 42851, 43656, 44273, 45005, 45656, 47465]
#
# Processing: 0032_8min_signal.csv
# File: 0032_8min_signal.csv
# True Positives (TP): 677
# False Positives (FP): 2
# False Negatives (FN): 6
# Accuracy: 0.99
# Precision: 1.00
# Recall: 0.99
# Detection Error Rate: 0.01
# False Positives (FP) at indices: [7, 47998]
# False Negatives (FN) at indices: [19321, 19388, 19463, 25086, 28166, 28458]
#
# Processing: 0035_8min_signal.csv
# File: 0035_8min_signal.csv
# True Positives (TP): 899
# False Positives (FP): 2
# False Negatives (FN): 0
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# Detection Error Rate: 0.00
# False Positives (FP) at indices: [7, 47999]
# False Negatives (FN) at indices: []
#
# Processing: 0038_8min_signal.csv
# File: 0038_8min_signal.csv
# True Positives (TP): 953
# False Positives (FP): 2
# False Negatives (FN): 3
# Accuracy: 0.99
# Precision: 1.00
# Recall: 1.00
# Detection Error Rate: 0.01
# False Positives (FP) at indices: [9, 47987]
# False Negatives (FN) at indices: [39188, 44007, 47995]
#
# Processing: 0103_8min_signal.csv
# File: 0103_8min_signal.csv
# True Positives (TP): 827
# False Positives (FP): 0
# False Negatives (FN): 0
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# Detection Error Rate: 0.00
# False Positives (FP) at indices: []
# False Negatives (FN) at indices: []
#
# Processing: 0104_8min_signal.csv
# File: 0104_8min_signal.csv
# True Positives (TP): 911
# False Positives (FP): 1
# False Negatives (FN): 0
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# Detection Error Rate: 0.00
# False Positives (FP) at indices: [5]
# False Negatives (FN) at indices: []
#
# Processing: 0105_8min_signal.csv
# File: 0105_8min_signal.csv
# True Positives (TP): 524
# False Positives (FP): 1
# False Negatives (FN): 3
# Accuracy: 0.99
# Precision: 1.00
# Recall: 0.99
# Detection Error Rate: 0.01
# False Positives (FP) at indices: [4]
# False Negatives (FN) at indices: [5550, 5649, 5743]
#
# Processing: 0115_8min_signal.csv
# File: 0115_8min_signal.csv
# True Positives (TP): 745
# False Positives (FP): 4
# False Negatives (FN): 5
# Accuracy: 0.99
# Precision: 0.99
# Recall: 0.99
# Detection Error Rate: 0.01
# False Positives (FP) at indices: [3011, 6922, 12169, 12304]
# False Negatives (FN) at indices: [2789, 7037, 7100, 12161, 12295]
#
# Processing: 0121_8min_signal.csv
# File: 0121_8min_signal.csv
# True Positives (TP): 580
# False Positives (FP): 0
# False Negatives (FN): 0
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# Detection Error Rate: 0.00
# False Positives (FP) at indices: []
# False Negatives (FN) at indices: []
#
# Processing: 0122_8min_signal.csv
# File: 0122_8min_signal.csv
# True Positives (TP): 588
# False Positives (FP): 1
# False Negatives (FN): 0
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# Detection Error Rate: 0.00
# False Positives (FP) at indices: [47998]
# False Negatives (FN) at indices: []
#
# Processing: 0123_8min_signal.csv
# File: 0123_8min_signal.csv
# True Positives (TP): 712
# False Positives (FP): 3
# False Negatives (FN): 3
# Accuracy: 0.99
# Precision: 1.00
# Recall: 1.00
# Detection Error Rate: 0.01
# False Positives (FP) at indices: [20864, 22476, 47989]
# False Negatives (FN) at indices: [22468, 29183, 31743]
#
# Processing: 0125_8min_signal.csv
# File: 0125_8min_signal.csv
# True Positives (TP): 626
# False Positives (FP): 1
# False Negatives (FN): 0
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# Detection Error Rate: 0.00
# False Positives (FP) at indices: [5]
# False Negatives (FN) at indices: []
#
# Processing: 0127_8min_signal.csv
# File: 0127_8min_signal.csv
# True Positives (TP): 614
# False Positives (FP): 1
# False Negatives (FN): 2
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# Detection Error Rate: 0.00
# False Positives (FP) at indices: [7798]
# False Negatives (FN) at indices: [7787, 7789]
#
# Processing: 0128_8min_signal.csv
# File: 0128_8min_signal.csv
# True Positives (TP): 540
# False Positives (FP): 0
# False Negatives (FN): 0
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# Detection Error Rate: 0.00
# False Positives (FP) at indices: []
# False Negatives (FN) at indices: []
#
# Processing: 0133_8min_signal.csv
# File: 0133_8min_signal.csv
# True Positives (TP): 569
# False Positives (FP): 1
# False Negatives (FN): 0
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# Detection Error Rate: 0.00
# False Positives (FP) at indices: [47998]
# False Negatives (FN) at indices: []
#
# Processing: 0134_8min_signal.csv
# File: 0134_8min_signal.csv
# True Positives (TP): 578
# False Positives (FP): 0
# False Negatives (FN): 0
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# Detection Error Rate: 0.00
# False Positives (FP) at indices: []
# False Negatives (FN) at indices: []
#
# Processing: 0142_8min_signal.csv
# File: 0142_8min_signal.csv
# True Positives (TP): 739
# False Positives (FP): 1
# False Negatives (FN): 0
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# Detection Error Rate: 0.00
# False Positives (FP) at indices: [47989]
# False Negatives (FN) at indices: []
#
# Processing: 0147_8min_signal.csv
# File: 0147_8min_signal.csv
# True Positives (TP): 517
# False Positives (FP): 24
# False Negatives (FN): 2
# Accuracy: 0.95
# Precision: 0.96
# Recall: 1.00
# Detection Error Rate: 0.05
# False Positives (FP) at indices: [3276, 4545, 6331, 6870, 9546, 10626, 15455, 16562, 19847, 22580, 24055, 24480, 24600, 24823, 28503, 28966, 32873, 37046, 39887, 39979, 40160, 42696, 47051, 47989]
# False Negatives (FN) at indices: [24470, 24813]
#
# Processing: 0148_8min_signal.csv
# File: 0148_8min_signal.csv
# True Positives (TP): 623
# False Positives (FP): 2
# False Negatives (FN): 0
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# Detection Error Rate: 0.00
# False Positives (FP) at indices: [4, 47999]
# False Negatives (FN) at indices: []
#
# Processing: 0149_8min_signal.csv
# File: 0149_8min_signal.csv
# True Positives (TP): 458
# False Positives (FP): 0
# False Negatives (FN): 0
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# Detection Error Rate: 0.00
# False Positives (FP) at indices: []
# False Negatives (FN) at indices: []
#
# Processing: 0150_8min_signal.csv
# File: 0150_8min_signal.csv
# True Positives (TP): 509
# False Positives (FP): 11
# False Negatives (FN): 2
# Accuracy: 0.98
# Precision: 0.98
# Recall: 1.00
# Detection Error Rate: 0.03
# False Positives (FP) at indices: [27153, 28610, 28807, 29381, 31044, 32036, 42754, 44292, 46599, 47943, 47991]
# False Negatives (FN) at indices: [31294, 31389]
#
# Processing: 0309_8min_signal.csv
# File: 0309_8min_signal.csv
# True Positives (TP): 509
# False Positives (FP): 1
# False Negatives (FN): 1
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# Detection Error Rate: 0.00
# False Positives (FP) at indices: [47987]
# False Negatives (FN) at indices: [38595]
#
# Processing: 0311_8min_signal.csv
# File: 0311_8min_signal.csv
# True Positives (TP): 555
# False Positives (FP): 0
# False Negatives (FN): 0
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# Detection Error Rate: 0.00
# False Positives (FP) at indices: []
# False Negatives (FN) at indices: []
#
# Processing: 0312_8min_signal.csv
# File: 0312_8min_signal.csv
# True Positives (TP): 419
# False Positives (FP): 1
# False Negatives (FN): 3
# Accuracy: 0.99
# Precision: 1.00
# Recall: 0.99
# Detection Error Rate: 0.01
# False Positives (FP) at indices: [47991]
# False Negatives (FN) at indices: [24201, 27133, 27903]
#
# Processing: 0313_8min_signal.csv
# File: 0313_8min_signal.csv
# True Positives (TP): 587
# False Positives (FP): 2
# False Negatives (FN): 0
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# Detection Error Rate: 0.00
# False Positives (FP) at indices: [5, 47999]
# False Negatives (FN) at indices: []
#
# Processing: 0322_8min_signal.csv
# File: 0322_8min_signal.csv
# True Positives (TP): 589
# False Positives (FP): 1
# False Negatives (FN): 0
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# Detection Error Rate: 0.00
# False Positives (FP) at indices: [5]
# False Negatives (FN) at indices: []
#
# Processing: 0325_8min_signal.csv
# File: 0325_8min_signal.csv
# True Positives (TP): 585
# False Positives (FP): 0
# False Negatives (FN): 0
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# Detection Error Rate: 0.00
# False Positives (FP) at indices: []
# False Negatives (FN) at indices: []
#
# Processing: 0328_8min_signal.csv
# File: 0328_8min_signal.csv
# True Positives (TP): 636
# False Positives (FP): 10
# False Negatives (FN): 0
# Accuracy: 0.98
# Precision: 0.98
# Recall: 1.00
# Detection Error Rate: 0.02
# False Positives (FP) at indices: [14646, 16146, 26104, 27896, 28664, 32366, 37161, 37721, 38267, 42453]
# False Negatives (FN) at indices: []
#
# Processing: 0329_8min_signal.csv
# File: 0329_8min_signal.csv
# True Positives (TP): 701
# False Positives (FP): 0
# False Negatives (FN): 0
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# Detection Error Rate: 0.00
# False Positives (FP) at indices: []
# False Negatives (FN) at indices: []
#
# Processing: 0330_8min_signal.csv
# File: 0330_8min_signal.csv
# True Positives (TP): 600
# False Positives (FP): 0
# False Negatives (FN): 0
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# Detection Error Rate: 0.00
# False Positives (FP) at indices: []
# False Negatives (FN) at indices: []
#
# Processing: 0331_8min_signal.csv
# File: 0331_8min_signal.csv
# True Positives (TP): 538
# False Positives (FP): 1
# False Negatives (FN): 0
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# Detection Error Rate: 0.00
# False Positives (FP) at indices: [47989]
# False Negatives (FN) at indices: []
#
# Processing: 0332_8min_signal.csv
# File: 0332_8min_signal.csv
# True Positives (TP): 590
# False Positives (FP): 0
# False Negatives (FN): 0
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# Detection Error Rate: 0.00
# False Positives (FP) at indices: []
# False Negatives (FN) at indices: []
#
# Processing: 0333_8min_signal.csv
# File: 0333_8min_signal.csv
# True Positives (TP): 559
# False Positives (FP): 0
# False Negatives (FN): 1
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# Detection Error Rate: 0.00
# False Positives (FP) at indices: []
# False Negatives (FN) at indices: [35325]
#
# Processing: 0370_8min_signal.csv
# File: 0370_8min_signal.csv
# True Positives (TP): 572
# False Positives (FP): 6
# False Negatives (FN): 5
# Accuracy: 0.98
# Precision: 0.99
# Recall: 0.99
# Detection Error Rate: 0.02
# False Positives (FP) at indices: [1902, 5690, 5938, 6561, 6789, 7645]
# False Negatives (FN) at indices: [1654, 1911, 5681, 5816, 5930]
#
#
# ===== Overall Performance =====
# Total Files Processed: 42
# Overall Accuracy: 0.99
# Overall Precision: 1.00
# Overall Recall: 1.00
# Overall Detection Error Rate (DER): 0.01
