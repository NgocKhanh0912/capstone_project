# %%
import os
import numpy as np
import pandas as pd

# %%
def detect_peaks_in_ppg_files(input_dir, output_dir, w_cycle=55, w_evt=9, beta=0.095):
    """
    Processes multiple PPG files, detects peaks, and saves the results into CSV files.
    
    Parameters:
    - input_dir: Path to the directory containing input PPG files.
    - output_dir: Path to the directory where the output files will be saved.
    - w_cycle: Window size for calculating the cycle moving average.
    - w_evt: Window size for calculating the event moving average.
    - beta: Scaling factor for the threshold.
    """
    
    # Loop over all files in the input directory
    for file_name in os.listdir(input_dir):
        if file_name.endswith('.csv'):  # Process only CSV files
            input_file = os.path.join(input_dir, file_name)
            print(f"Processing file: {file_name}")
            
            # Read the PPG data from the file
            ppg_data = pd.read_csv(input_file, header=None)
            signal = np.asarray(ppg_data.iloc[:, 0], dtype=np.float64)  # Assume the PPG data is in the first column
            
            # Shift the signal to eliminate negative values
            min_signal = np.min(signal)
            if min_signal < 0:
                signal = signal - min_signal  # Shift signal so the minimum value becomes 0 or greater
            
            # Enhance the signal (square the values)
            signal = signal * signal
            
            # Initialize arrays for moving averages and thresholds
            ma_cycle = np.zeros_like(signal, dtype=np.float64)
            ma_evt = np.zeros_like(signal, dtype=np.float64)
            mean_signal = np.mean(signal)
            mean = np.full(len(signal), mean_signal)
            threshold_1 = np.zeros_like(signal, dtype=np.float64)
            block_of_interest = np.zeros_like(signal, dtype=np.float64)
            peak_index_arr = []
            
            # Calculate the Event Duration Moving Average
            for i in range((w_evt - 1) // 2, len(signal) - ((w_evt - 1) // 2)):
                ma_evt[i] = np.mean(signal[i - (w_evt - 1) // 2 : i + (w_evt - 1) // 2 + 1])
            
            # Calculate the Event Cycle Moving Average
            for i in range((w_cycle - 1) // 2, len(signal) - ((w_cycle - 1) // 2)):
                ma_cycle[i] = np.mean(signal[i - (w_cycle - 1) // 2 : i + (w_cycle - 1) // 2 + 1])
            
            # Calculate the Threshold for Block of Interest
            for i in range(len(signal)):
                threshold_1[i] = ma_cycle[i] + beta * mean[i]
            
            # Generate the Block of Interest
            for i in range(len(signal)):
                if (ma_evt[i] > threshold_1[i]) and (ma_cycle[i] != 0):
                    block_of_interest[i] = 1
                else:
                    block_of_interest[i] = 0
            
            # Peak detector logic
            start_block = 0
            stop_block = 0
            peak = 0
            peak_index = 0
            block_num = 0
            
            for i in range(len(block_of_interest) - 1):
                if (block_of_interest[i + 1] - block_of_interest[i]) == 1:
                    start_block = i
                if (block_of_interest[i] - block_of_interest[i + 1]) == 1:
                    stop_block = i
                    if (stop_block - start_block) >= w_evt:
                        peak = signal[start_block]
                        for j in range(start_block, stop_block + 1):
                            if signal[j] > peak:
                                peak = signal[j]
                                peak_index = j
                        peak_index_arr.append(peak_index)
                        block_num += 1
            
            # Save the peak indices to a CSV file
            output_file = os.path.join(output_dir, f"{file_name.replace('.csv', '')}_labeled_peaks.csv")
            pd.DataFrame(peak_index_arr).to_csv(output_file, header=False, index=False)
            print(f"Peaks saved to: {output_file}")

# %%
input_train_dir = 'I:/dilated_cnn_peak_detection_model_data/train/train_data/data'
output_train_dir = 'I:/dilated_cnn_peak_detection_model_data/train/train_data/label'
input_test_dir = 'I:/dilated_cnn_peak_detection_model_data/test/test_data/data'
output_test_dir = 'I:/dilated_cnn_peak_detection_model_data/test/test_data/label'

detect_peaks_in_ppg_files(input_train_dir, output_train_dir)
detect_peaks_in_ppg_files(input_test_dir, output_test_dir)
# Out:
# Processing file: p000608-2167-03-09-11-54.csv
# Peaks saved to: I:/dilated_cnn_peak_detection_model_data/train/train_data/label\
csv
# Peaks saved to: I:/dilated_cnn_peak_detection_model_data/train/train_data/label\p029512-2188-02-27-18-10_labeled_peaks.csv
# Processing file: p043613-2185-01-18-23-52.csv
# Peaks saved to: I:/dilated_cnn_peak_detection_model_data/train/train_data/label\p043613-2185-01-18-23-52_labeled_peaks.csv
# Processing file: p050089-2157-08-23-16-37.csv
# Peaks saved to: I:/dilated_cnn_peak_detection_model_data/train/train_data/label\p050089-2157-08-23-16-37_labeled_peaks.csv
# Processing file: p050384-2195-01-30-02-21.csv
# Peaks saved to: I:/dilated_cnn_peak_detection_model_data/train/train_data/label\p050384-2195-01-30-02-21_labeled_peaks.csv
# Processing file: p050384-2195-01-30-16-17.csv
# Peaks saved to: I:/dilated_cnn_peak_detection_model_data/train/train_data/label\p050384-2195-01-30-16-17_labeled_peaks.csv
# Processing file: p055204-2132-06-30-09-34.csv
# Peaks saved to: I:/dilated_cnn_peak_detection_model_data/train/train_data/label\p055204-2132-06-30-09-34_labeled_peaks.csv
# Processing file: p055204-2132-07-02-00-25.csv
# Peaks saved to: I:/dilated_cnn_peak_detection_model_data/train/train_data/label\p055204-2132-07-02-00-25_labeled_peaks.csv
# Processing file: p058932-2120-10-13-23-15.csv
# Peaks saved to: I:/dilated_cnn_peak_detection_model_data/train/train_data/label\p058932-2120-10-13-23-15_labeled_peaks.csv
# Processing file: p062160-2153-10-03-05-39.csv
# Peaks saved to: I:/dilated_cnn_peak_detection_model_data/train/train_data/label\p062160-2153-10-03-05-39_labeled_peaks.csv
# Processing file: p062160-2153-10-03-14-49.csv
# Peaks saved to: I:/dilated_cnn_peak_detection_model_data/train/train_data/label\p062160-2153-10-03-14-49_labeled_peaks.csv
# Processing file: p063039-2157-03-29-13-35.csv
# Peaks saved to: I:/dilated_cnn_peak_detection_model_data/train/train_data/label\p063039-2157-03-29-13-35_labeled_peaks.csv
# Processing file: p063628-2176-07-02-20-38.csv
# Peaks saved to: I:/dilated_cnn_peak_detection_model_data/train/train_data/label\p063628-2176-07-02-20-38_labeled_peaks.csv
# Processing file: p063628-2176-07-04-11-30.csv
# Peaks saved to: I:/dilated_cnn_peak_detection_model_data/train/train_data/label\p063628-2176-07-04-11-30_labeled_peaks.csv
# Processing file: p063628-2176-07-05-17-12.csv
# Peaks saved to: I:/dilated_cnn_peak_detection_model_data/train/train_data/label\p063628-2176-07-05-17-12_labeled_peaks.csv
# Processing file: p068956-2107-04-21-16-05.csv
# Peaks saved to: I:/dilated_cnn_peak_detection_model_data/train/train_data/label\p068956-2107-04-21-16-05_labeled_peaks.csv
# Processing file: p068956-2107-04-21-16-10.csv
# Peaks saved to: I:/dilated_cnn_peak_detection_model_data/train/train_data/label\p068956-2107-04-21-16-10_labeled_peaks.csv
# Processing file: p069339-2133-12-09-21-14.csv
# Peaks saved to: I:/dilated_cnn_peak_detection_model_data/train/train_data/label\p069339-2133-12-09-21-14_labeled_peaks.csv
# Processing file: p069339-2133-12-10-22-32.csv
# Peaks saved to: I:/dilated_cnn_peak_detection_model_data/train/train_data/label\p069339-2133-12-10-22-32_labeled_peaks.csv
# Processing file: p075371-2119-08-22-00-53.csv
# Peaks saved to: I:/dilated_cnn_peak_detection_model_data/train/train_data/label\p075371-2119-08-22-00-53_labeled_peaks.csv
# Processing file: p075371-2119-08-22-17-30.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 6
#       3 input_test_dir = 'I:/dilated_cnn_peak_detection_model_data/test/test_data/data'
#       4 output_test_dir = 'I:/dilated_cnn_peak_detection_model_data/test/test_data/label'
# ----> 6 detect_peaks_in_ppg_files(input_train_dir, output_train_dir)
#       7 detect_peaks_in_ppg_files(input_test_dir, output_test_dir)
#
# Cell In[5], line 41, in detect_peaks_in_ppg_files(input_dir, output_dir, w_cycle, w_evt, beta)
#      39 # Calculate the Event Cycle Moving Average
#      40 for i in range((w_cycle - 1) // 2, len(signal) - ((w_cycle - 1) // 2)):
# ---> 41     ma_cycle[i] = np.mean(signal[i - (w_cycle - 1) // 2 : i + (w_cycle - 1) // 2 + 1])
#      43 # Calculate the Threshold for Block of Interest
#      44 for i in range(len(signal)):
#
# File c:\Python312\Lib\site-packages\numpy\_core\fromnumeric.py:3596, in mean(a, axis, dtype, out, keepdims, where)
#    3593     else:
#    3594         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3596 return _methods._mean(a, axis=axis, dtype=dtype,
#    3597                       out=out, **kwargs)
#
# File c:\Python312\Lib\site-packages\numpy\_core\_methods.py:110, in _mean(a, axis, dtype, out, keepdims, where)
#     107     else:
#     108         return um.clip(a, min, max, out=out, **kwargs)
# --> 110 def _mean(a, axis=None, dtype=None, out=None, keepdims=False, *, where=True):
#     111     arr = asanyarray(a)
#     113     is_float16_result = False
#
# KeyboardInterrupt:
