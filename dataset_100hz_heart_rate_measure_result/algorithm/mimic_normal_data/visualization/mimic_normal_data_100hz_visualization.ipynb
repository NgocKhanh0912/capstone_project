# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
mimic_normal_ppg_filepath = "../data/mimic_normal_data_100hz.csv"

mimic_normal_ppg_data = pd.read_csv(mimic_normal_ppg_filepath, nrows = 5000)

# %%
plt.figure(figsize = (200, 6))
sns.lineplot(data = mimic_normal_ppg_data)
# Out:
# <Axes: >
