# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
ppg_golden_filepath = "../golden_data/ppg_golden_data.csv"

ppg_golden_data = pd.read_csv(ppg_golden_filepath, nrows = 10000)

# %%
plt.figure(figsize = (200,6))
sns.lineplot(data = ppg_golden_data)
# Out:
# <Axes: >
